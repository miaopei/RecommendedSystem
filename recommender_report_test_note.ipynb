# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
from collections import Counter
import tensorflow as tf

import os
import pickle
import re
from tensorflow.python.ops import math_ops

from matplotlib import pyplot as plt

import seaborn as sns

# %matplotlib inline

# %%
users_title = ['UserID', 'Gender', 'Age', 'JobID', 'Zip-code']
users = pd.read_table('./ml-1m/users.dat', sep='::', header=None, names=users_title, engine = 'python')
users = users.filter(regex='UserID|Gender|Age|JobID')
users_orig = users.values
#改变User数据中性别和年龄
gender_map = {'F':0, 'M':1}
users['Gender'] = users['Gender'].map(gender_map)

age_map = {item:index for index,item in enumerate([1,18,25,35,45,50,56])}
users['Age'] = users['Age'].map(age_map)

# %%
#读取Movie数据集
movies_title = ['MovieID', 'Title', 'Genres']
movies = pd.read_table('./ml-1m/movies.dat', sep='::', header=None, names=movies_title, engine = 'python')
movies_orig = movies.values

# %%
movies.head()
# Out:
#    MovieID                               Title                        Genres
# 0        1                    Toy Story (1995)   Animation|Children's|Comedy
# 1        2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2        3             Grumpier Old Men (1995)                Comedy|Romance
# 3        4            Waiting to Exhale (1995)                  Comedy|Drama
# 4        5  Father of the Bride Part II (1995)                        Comedy

# %%
#将Title中的年份去掉
pattern = re.compile(r'^(.*)\((\d+)\)$')
title_map = {item:pattern.match(item).group(1) for index,item in enumerate(set(movies['Title']))}
movies['Title'] = movies['Title'].map(title_map)

# %%
movies.head()
# Out:
#    MovieID                         Title                        Genres
# 0        1                    Toy Story    Animation|Children's|Comedy
# 1        2                      Jumanji   Adventure|Children's|Fantasy
# 2        3             Grumpier Old Men                 Comedy|Romance
# 3        4            Waiting to Exhale                   Comedy|Drama
# 4        5  Father of the Bride Part II                         Comedy

# %%
max_title_map = {item:len(item.split()) for index,item in enumerate(set(movies['Title']))}

max(max_title_map.items(), key=lambda x: x[1])
# Out:
# ('Old Lady Who Walked in the Sea, The (Vieille qui marchait dans la mer, La) ',
#  15)

# %%
title_map
# Out:
# {'Somewhere in Time (1980)': 'Somewhere in Time ',
#  'Drop Dead Gorgeous (1999)': 'Drop Dead Gorgeous ',
#  "Devil's Brigade, The (1968)": "Devil's Brigade, The ",
#  'Prick Up Your Ears (1987)': 'Prick Up Your Ears ',
#  'Algiers (1938)': 'Algiers ',
#  'Sliver (1993)': 'Sliver ',
#  'Thing, The (1982)': 'Thing, The ',
#  'Smiling Fish and Goat on Fire (1999)': 'Smiling Fish and Goat on Fire ',
#  'A Chef in Love (1996)': 'A Chef in Love ',
#  'Year of the Horse (1997)': 'Year of the Horse ',
#  'Paralyzing Fear: The Story of Polio in America, A (1998)': 'Paralyzing Fear: The Story of Polio in America, A ',
#  'Fear of a Black Hat (1993)': 'Fear of a Black Hat ',
#  'Mercury Rising (1998)': 'Mercury Rising ',
#  'Detroit 9000 (1973)': 'Detroit 9000 ',
#  'Morning After, The (1986)': 'Morning After, The ',
#  'Fifth Element, The (1997)': 'Fifth Element, The ',
#  'Shall We Dance? (Shall We Dansu?) (1996)': 'Shall We Dance? (Shall We Dansu?) ',
#  "Pot O' Gold (1941)": "Pot O' Gold ",
#  'This World, Then the Fireworks (1996)': 'This World, Then the Fireworks ',
#  'Halloween (1978)': 'Halloween ',
#  'Phantoms (1998)': 'Phantoms ',
#  'Double Team (1997)': 'Double Team ',
#  'Visitors, The (Les Visiteurs) (1993)': 'Visitors, The (Les Visiteurs) ',
#  'Hell in the Pacific (1968)': 'Hell in the Pacific ',
#  'Quatermass II (1957)': 'Quatermass II ',
#  'Schlafes Bruder (Brother of Sleep) (1995)': 'Schlafes Bruder (Brother of Sleep) ',
#  'Out of Africa (1985)': 'Out of Africa ',
#  'Men of Means (1998)': 'Men of Means ',
#  'Sting, The (1973)': 'Sting, The ',
#  'I Confess (1953)': 'I Confess ',
#  'Roadside Prophets (1992)': 'Roadside Prophets ',
#  'Parallel Sons (1995)': 'Parallel Sons ',
#  'Life with Mikey (1993)': 'Life with Mikey ',
#  'Muppet Christmas Carol, The (1992)': 'Muppet Christmas Carol, The ',
#  'To Die For (1995)': 'To Die For ',
#  'Pushing Hands (1992)': 'Pushing Hands ',
#  'Three Colors: Red (1994)': 'Three Colors: Red ',
#  'Amos & Andrew (1993)': 'Amos & Andrew ',
#  'Hurricane, The (1999)': 'Hurricane, The ',
#  'Third Man, The (1949)': 'Third Man, The ',
#  'Napoleon and Samantha (1972)': 'Napoleon and Samantha ',
#  'Mars Attacks! (1996)': 'Mars Attacks! ',
#  'Twelve Chairs, The (1970)': 'Twelve Chairs, The ',
#  'Laura (1944)': 'Laura ',
#  'Waking Ned Devine (1998)': 'Waking Ned Devine ',
#  'Battle of the Sexes, The (1959)': 'Battle of the Sexes, The ',
#  'Mickey Blue Eyes (1999)': 'Mickey Blue Eyes ',
#  'Miracle on 34th Street (1947)': 'Miracle on 34th Street ',
#  'How to Make an American Quilt (1995)': 'How to Make an American Quilt ',
#  'Snow White and the Seven Dwarfs (1937)': 'Snow White and the Seven Dwarfs ',
#  'Dial M for Murder (1954)': 'Dial M for Murder ',
#  'Bulletproof (1996)': 'Bulletproof ',
#  'Hustler, The (1961)': 'Hustler, The ',
#  'Devil Rides Out, The (1968)': 'Devil Rides Out, The ',
#  'Power 98 (1995)': 'Power 98 ',
#  'Seventh Heaven (Le Septi�me ciel) (1997)': 'Seventh Heaven (Le Septi�me ciel) ',
#  'Aim�e & Jaguar (1999)': 'Aim�e & Jaguar ',
#  'Star Trek: Generations (1994)': 'Star Trek: Generations ',
#  'Frank and Ollie (1995)': 'Frank and Ollie ',
#  'Babe (1995)': 'Babe ',
#  'Friday the 13th: The Final Chapter (1984)': 'Friday the 13th: The Final Chapter ',
#  "Angela's Ashes (1999)": "Angela's Ashes ",
#  'Bells, The (1926)': 'Bells, The ',
#  'Miracle on 34th Street (1994)': 'Miracle on 34th Street ',
#  'Parent Trap, The (1998)': 'Parent Trap, The ',
#  'Overnight Delivery (1996)': 'Overnight Delivery ',
#  'Tales from the Darkside: The Movie (1990)': 'Tales from the Darkside: The Movie ',
#  'Big Carnival, The (1951)': 'Big Carnival, The ',
#  'Body Parts (1991)': 'Body Parts ',
#  'Stupids, The (1996)': 'Stupids, The ',
#  'Hook (1991)': 'Hook ',
#  "What's Love Got to Do with It? (1993)": "What's Love Got to Do with It? ",
#  'Scorta, La (1993)': 'Scorta, La ',
#  'Fluke (1995)': 'Fluke ',
#  'Hollow Reed (1996)': 'Hollow Reed ',
#  'Wolf Man, The (1941)': 'Wolf Man, The ',
#  'Key Largo (1948)': 'Key Largo ',
#  'Diebinnen (1995)': 'Diebinnen ',
#  'Return to Me (2000)': 'Return to Me ',
#  'Scream 3 (2000)': 'Scream 3 ',
#  'Man with Two Brains, The (1983)': 'Man with Two Brains, The ',
#  'Music From Another Room (1998)': 'Music From Another Room ',
#  'Any Number Can Win (M�lodie en sous-sol ) (1963)': 'Any Number Can Win (M�lodie en sous-sol ) ',
#  'Waking the Dead (1999)': 'Waking the Dead ',
#  'First Knight (1995)': 'First Knight ',
#  '8 Seconds (1994)': '8 Seconds ',
#  "Can't Hardly Wait (1998)": "Can't Hardly Wait ",
#  'Halloween: H20 (1998)': 'Halloween: H20 ',
#  'Phantom of the Opera, The (1943)': 'Phantom of the Opera, The ',
#  'Last September, The (1999)': 'Last September, The ',
#  'Being John Malkovich (1999)': 'Being John Malkovich ',
#  'To Be or Not to Be (1942)': 'To Be or Not to Be ',
#  "Porky's II: The Next Day (1983)": "Porky's II: The Next Day ",
#  'Naked in New York (1994)': 'Naked in New York ',
#  'Hellraiser: Bloodline (1996)': 'Hellraiser: Bloodline ',
#  'Sleeping Beauty (1959)': 'Sleeping Beauty ',
#  'Take the Money and Run (1969)': 'Take the Money and Run ',
#  'Nightmare on Elm Street 4: The Dream Master, A (1988)': 'Nightmare on Elm Street 4: The Dream Master, A ',
#  'Civil Action, A (1998)': 'Civil Action, A ',
#  'Saludos Amigos (1943)': 'Saludos Amigos ',
#  'Blazing Saddles (1974)': 'Blazing Saddles ',
#  'Fletch (1985)': 'Fletch ',
#  'Radioland Murders (1994)': 'Radioland Murders ',
#  "Wayne's World (1992)": "Wayne's World ",
#  'Poison Ivy II (1995)': 'Poison Ivy II ',
#  'Pushing Tin (1999)': 'Pushing Tin ',
#  'Associate, The (1996)': 'Associate, The ',
#  'M. Butterfly (1993)': 'M. Butterfly ',
#  "Billy's Hollywood Screen Kiss (1997)": "Billy's Hollywood Screen Kiss ",
#  'Desperate Measures (1998)': 'Desperate Measures ',
#  'Center Stage (2000)': 'Center Stage ',
#  'Mephisto (1981)': 'Mephisto ',
#  'True Crime (1999)': 'True Crime ',
#  'Bossa Nova (1999)': 'Bossa Nova ',
#  'Patton (1970)': 'Patton ',
#  'This Is My Father (1998)': 'This Is My Father ',
#  'Dry Cleaning (Nettoyage � sec) (1997)': 'Dry Cleaning (Nettoyage � sec) ',
#  'Planet of the Apes (1968)': 'Planet of the Apes ',
#  'Up at the Villa (2000)': 'Up at the Villa ',
#  'Circle of Friends (1995)': 'Circle of Friends ',
#  'Bitter Moon (1992)': 'Bitter Moon ',
#  'Temptress Moon (Feng Yue) (1996)': 'Temptress Moon (Feng Yue) ',
#  'Not One Less (Yi ge dou bu neng shao) (1999)': 'Not One Less (Yi ge dou bu neng shao) ',
#  'Black Mask (Hak hap) (1996)': 'Black Mask (Hak hap) ',
#  'Entrapment (1999)': 'Entrapment ',
#  'House Party 3 (1994)': 'House Party 3 ',
#  'Under Capricorn (1949)': 'Under Capricorn ',
#  'Everything You Always Wanted to Know About Sex (1972)': 'Everything You Always Wanted to Know About Sex ',
#  'Man Without a Face, The (1993)': 'Man Without a Face, The ',
#  'Short Cuts (1993)': 'Short Cuts ',
#  "She's All That (1999)": "She's All That ",
#  "Shaft's Big Score! (1972)": "Shaft's Big Score! ",
#  'Faraway, So Close (In Weiter Ferne, So Nah!) (1993)': 'Faraway, So Close (In Weiter Ferne, So Nah!) ',
#  'He Got Game (1998)': 'He Got Game ',
#  'Ideal Husband, An (1999)': 'Ideal Husband, An ',
#  'War of the Worlds, The (1953)': 'War of the Worlds, The ',
#  'Love and Death (1975)': 'Love and Death ',
#  'Boiler Room (2000)': 'Boiler Room ',
#  'Superman II (1980)': 'Superman II ',
#  'Desert Blue (1999)': 'Desert Blue ',
#  'My Tutor (1983)': 'My Tutor ',
#  'Perfect Storm, The (2000)': 'Perfect Storm, The ',
#  'Total Recall (1990)': 'Total Recall ',
#  'Hot Shots! Part Deux (1993)': 'Hot Shots! Part Deux ',
#  'Secrets & Lies (1996)': 'Secrets & Lies ',
#  'Diva (1981)': 'Diva ',
#  "Freddy's Dead: The Final Nightmare (1991)": "Freddy's Dead: The Final Nightmare ",
#  'Thinner (1996)': 'Thinner ',
#  'Pillow Book, The (1995)': 'Pillow Book, The ',
#  "Things to Do in Denver when You're Dead (1995)": "Things to Do in Denver when You're Dead ",
#  'Deep Rising (1998)': 'Deep Rising ',
#  'Net, The (1995)': 'Net, The ',
#  'Curdled (1996)': 'Curdled ',
#  'Beans of Egypt, Maine, The (1994)': 'Beans of Egypt, Maine, The ',
#  'Hippie Revolution, The (1996)': 'Hippie Revolution, The ',
#  'Cool as Ice (1991)': 'Cool as Ice ',
#  'Blown Away (1994)': 'Blown Away ',
#  'Outbreak (1995)': 'Outbreak ',
#  'Dick (1999)': 'Dick ',
#  'My Fellow Americans (1996)': 'My Fellow Americans ',
#  'Truth About Cats & Dogs, The (1996)': 'Truth About Cats & Dogs, The ',
#  'Color Me Blood Red (1965)': 'Color Me Blood Red ',
#  'Following (1998)': 'Following ',
#  'Puppet Master 5: The Final Chapter (1994)': 'Puppet Master 5: The Final Chapter ',
#  'Sonic Outlaws (1995)': 'Sonic Outlaws ',
#  'Something Wicked This Way Comes (1983)': 'Something Wicked This Way Comes ',
#  'My Life in Pink (Ma vie en rose) (1997)': 'My Life in Pink (Ma vie en rose) ',
#  'Ugly, The (1997)': 'Ugly, The ',
#  'Jackie Brown (1997)': 'Jackie Brown ',
#  'Outside Ozona (1998)': 'Outside Ozona ',
#  'Passion in the Desert (1998)': 'Passion in the Desert ',
#  'Otello (1986)': 'Otello ',
#  'Ace Ventura: When Nature Calls (1995)': 'Ace Ventura: When Nature Calls ',
#  'Damien: Omen II (1978)': 'Damien: Omen II ',
#  "Dead Men Don't Wear Plaid (1982)": "Dead Men Don't Wear Plaid ",
#  'Breaks, The (1999)': 'Breaks, The ',
#  'Westworld (1973)': 'Westworld ',
#  'City of Lost Children, The (1995)': 'City of Lost Children, The ',
#  'Bridge on the River Kwai, The (1957)': 'Bridge on the River Kwai, The ',
#  'Immortal Beloved (1994)': 'Immortal Beloved ',
#  'Rocketship X-M (1950)': 'Rocketship X-M ',
#  'Hotel de Love (1996)': 'Hotel de Love ',
#  'Velocity of Gary, The (1998)': 'Velocity of Gary, The ',
#  'Anatomy of a Murder (1959)': 'Anatomy of a Murder ',
#  "School of Flesh, The (L' �cole de la chair) (1998)": "School of Flesh, The (L' �cole de la chair) ",
#  'King of Masks, The (Bian Lian) (1996)': 'King of Masks, The (Bian Lian) ',
#  'Meet Joe Black (1998)': 'Meet Joe Black ',
#  'Scream of Stone (Schrei aus Stein) (1991)': 'Scream of Stone (Schrei aus Stein) ',
#  'Nutty Professor, The (1996)': 'Nutty Professor, The ',
#  'Police Academy 6: City Under Siege (1989)': 'Police Academy 6: City Under Siege ',
#  'Strangers on a Train (1951)': 'Strangers on a Train ',
#  'Frankie Starlight (1995)': 'Frankie Starlight ',
#  'High Art (1998)': 'High Art ',
#  'Mis�rables, Les (1998)': 'Mis�rables, Les ',
#  'Primary Colors (1998)': 'Primary Colors ',
#  'Howling II: Your Sister Is a Werewolf (1985)': 'Howling II: Your Sister Is a Werewolf ',
#  "Cat's Eye (1985)": "Cat's Eye ",
#  'House II: The Second Story (1987)': 'House II: The Second Story ',
#  'Single Girl, A (La Fille Seule) (1995)': 'Single Girl, A (La Fille Seule) ',
#  'M*A*S*H (1970)': 'M*A*S*H ',
#  'Metro (1997)': 'Metro ',
#  'Enemy of the State (1998)': 'Enemy of the State ',
#  'Leatherface: Texas Chainsaw Massacre III (1990)': 'Leatherface: Texas Chainsaw Massacre III ',
#  'Phantasm IV: Oblivion (1998)': 'Phantasm IV: Oblivion ',
#  'Paris Is Burning (1990)': 'Paris Is Burning ',
#  'Galaxy Quest (1999)': 'Galaxy Quest ',
#  'Real Genius (1985)': 'Real Genius ',
#  'Cops and Robbersons (1994)': 'Cops and Robbersons ',
#  'Nemesis 2: Nebula (1995)': 'Nemesis 2: Nebula ',
#  'Anne Frank Remembered (1995)': 'Anne Frank Remembered ',
#  'Tombstone (1993)': 'Tombstone ',
#  'Speechless (1994)': 'Speechless ',
#  'Larger Than Life (1996)': 'Larger Than Life ',
#  'West Side Story (1961)': 'West Side Story ',
#  'Network (1976)': 'Network ',
#  'Running Free (2000)': 'Running Free ',
#  'Babyfever (1994)': 'Babyfever ',
#  'Knock Off (1998)': 'Knock Off ',
#  'Species (1995)': 'Species ',
#  'Romeo and Juliet (1968)': 'Romeo and Juliet ',
#  'Woman on Top (2000)': 'Woman on Top ',
#  'Ladybird Ladybird (1994)': 'Ladybird Ladybird ',
#  'Chasers (1994)': 'Chasers ',
#  'White Boys (1999)': 'White Boys ',
#  'Junk Mail (1997)': 'Junk Mail ',
#  'Quiz Show (1994)': 'Quiz Show ',
#  'Nelly & Monsieur Arnaud (1995)': 'Nelly & Monsieur Arnaud ',
#  'Ratchet (1996)': 'Ratchet ',
#  'Sunshine (1999)': 'Sunshine ',
#  'Fandango (1985)': 'Fandango ',
#  'Heaven Can Wait (1978)': 'Heaven Can Wait ',
#  'Year My Voice Broke, The (1987)': 'Year My Voice Broke, The ',
#  'Hunger, The (1983)': 'Hunger, The ',
#  'Magic Hunter (1994)': 'Magic Hunter ',
#  'Tigger Movie, The (2000)': 'Tigger Movie, The ',
#  'Prom Night III: The Last Kiss (1989)': 'Prom Night III: The Last Kiss ',
#  'Patch Adams (1998)': 'Patch Adams ',
#  'Heavy Metal (1981)': 'Heavy Metal ',
#  'Map of the World, A (1999)': 'Map of the World, A ',
#  'Night of the Creeps (1986)': 'Night of the Creeps ',
#  'Wisdom (1986)': 'Wisdom ',
#  'Amistad (1997)': 'Amistad ',
#  'Reservoir Dogs (1992)': 'Reservoir Dogs ',
#  'Maverick (1994)': 'Maverick ',
#  'Predator 2 (1990)': 'Predator 2 ',
#  'Tin Men (1987)': 'Tin Men ',
#  "Joe's Apartment (1996)": "Joe's Apartment ",
#  'Fear and Loathing in Las Vegas (1998)': 'Fear and Loathing in Las Vegas ',
#  'Manhattan (1979)': 'Manhattan ',
#  'King and I, The (1956)': 'King and I, The ',
#  'Drive Me Crazy (1999)': 'Drive Me Crazy ',
#  'Smoke Signals (1998)': 'Smoke Signals ',
#  'My Best Fiend (Mein liebster Feind) (1999)': 'My Best Fiend (Mein liebster Feind) ',
#  'Nightmares (1983)': 'Nightmares ',
#  'Madness of King George, The (1994)': 'Madness of King George, The ',
#  'Computer Wore Tennis Shoes, The (1970)': 'Computer Wore Tennis Shoes, The ',
#  'Risky Business (1983)': 'Risky Business ',
#  'Story of Us, The (1999)': 'Story of Us, The ',
#  'Bluebeard (1944)': 'Bluebeard ',
#  'Event Horizon (1997)': 'Event Horizon ',
#  'Beach, The (2000)': 'Beach, The ',
#  'Last Time I Committed Suicide, The (1997)': 'Last Time I Committed Suicide, The ',
#  'Peggy Sue Got Married (1986)': 'Peggy Sue Got Married ',
#  'Elephant Man, The (1980)': 'Elephant Man, The ',
#  'Voyage to the Beginning of the World (1997)': 'Voyage to the Beginning of the World ',
#  "Jumpin' Jack Flash (1986)": "Jumpin' Jack Flash ",
#  'Dead Man (1995)': 'Dead Man ',
#  'Very Bad Things (1998)': 'Very Bad Things ',
#  'Robin Hood: Prince of Thieves (1991)': 'Robin Hood: Prince of Thieves ',
#  'Touki Bouki (Journey of the Hyena) (1973)': 'Touki Bouki (Journey of the Hyena) ',
#  'Happy Go Lovely (1951)': 'Happy Go Lovely ',
#  "Prizzi's Honor (1985)": "Prizzi's Honor ",
#  'Persuasion (1995)': 'Persuasion ',
#  'Father of the Bride (1950)': 'Father of the Bride ',
#  'Buck and the Preacher (1972)': 'Buck and the Preacher ',
#  'Wild Reeds (1994)': 'Wild Reeds ',
#  'Late Bloomers (1996)': 'Late Bloomers ',
#  'Negotiator, The (1998)': 'Negotiator, The ',
#  'Barefoot Executive, The (1971)': 'Barefoot Executive, The ',
#  'Brief Encounter (1946)': 'Brief Encounter ',
#  'Midnight Run (1988)': 'Midnight Run ',
#  'Blood Spattered Bride, The (La Novia Ensangrentada) (1972)': 'Blood Spattered Bride, The (La Novia Ensangrentada) ',
#  'Shaft (2000)': 'Shaft ',
#  'Addams Family, The (1991)': 'Addams Family, The ',
#  'Smoke (1995)': 'Smoke ',
#  'Teaching Mrs. Tingle (1999)': 'Teaching Mrs. Tingle ',
#  'Children of the Corn IV: The Gathering (1996)': 'Children of the Corn IV: The Gathering ',
#  'Total Eclipse (1995)': 'Total Eclipse ',
#  'Lucie Aubrac (1997)': 'Lucie Aubrac ',
#  "Felicia's Journey (1999)": "Felicia's Journey ",
#  "White Men Can't Jump (1992)": "White Men Can't Jump ",
#  'Blood In, Blood Out (a.k.a. Bound by Honor) (1993)': 'Blood In, Blood Out (a.k.a. Bound by Honor) ',
#  'Prophecy, The (1995)': 'Prophecy, The ',
#  'Clockwork Orange, A (1971)': 'Clockwork Orange, A ',
#  'Pink Floyd - The Wall (1982)': 'Pink Floyd - The Wall ',
#  'Haunting, The (1999)': 'Haunting, The ',
#  'Bay of Blood (Reazione a catena) (1971)': 'Bay of Blood (Reazione a catena) ',
#  'Nightmare Before Christmas, The (1993)': 'Nightmare Before Christmas, The ',
#  'Halloween 5: The Revenge of Michael Myers (1989)': 'Halloween 5: The Revenge of Michael Myers ',
#  'Cabaret (1972)': 'Cabaret ',
#  'Insider, The (1999)': 'Insider, The ',
#  'Tales from the Crypt Presents: Bordello of Blood (1996)': 'Tales from the Crypt Presents: Bordello of Blood ',
#  'Purple Rose of Cairo, The (1985)': 'Purple Rose of Cairo, The ',
#  'Madagascar Skin (1995)': 'Madagascar Skin ',
#  'Stars and Bars (1988)': 'Stars and Bars ',
#  'Allnighter, The (1987)': 'Allnighter, The ',
#  'Jail Bait (1954)': 'Jail Bait ',
#  'Dudley Do-Right (1999)': 'Dudley Do-Right ',
#  'First Love, Last Rites (1997)': 'First Love, Last Rites ',
#  'Trip to Bountiful, The (1985)': 'Trip to Bountiful, The ',
#  'Commandments (1997)': 'Commandments ',
#  "We're No Angels (1989)": "We're No Angels ",
#  "Besieged (L' Assedio) (1998)": "Besieged (L' Assedio) ",
#  'No Escape (1994)': 'No Escape ',
#  'Citizen Ruth (1996)': 'Citizen Ruth ',
#  'Small Soldiers (1998)': 'Small Soldiers ',
#  'Kaspar Hauser (1993)': 'Kaspar Hauser ',
#  'American Graffiti (1973)': 'American Graffiti ',
#  'Hurricane Streets (1998)': 'Hurricane Streets ',
#  "Swept Away (Travolti da un insolito destino nell'azzurro mare d'Agosto) (1975)": "Swept Away (Travolti da un insolito destino nell'azzurro mare d'Agosto) ",
#  'Mirage (1995)': 'Mirage ',
#  'City of Industry (1997)': 'City of Industry ',
#  'Terminator 2: Judgment Day (1991)': 'Terminator 2: Judgment Day ',
#  "Dante's Peak (1997)": "Dante's Peak ",
#  'Problem Child (1990)': 'Problem Child ',
#  'Phoenix (1998)': 'Phoenix ',
#  'My Chauffeur (1986)': 'My Chauffeur ',
#  'Savior (1998)': 'Savior ',
#  'Air Force One (1997)': 'Air Force One ',
#  'Penitentiary II (1982)': 'Penitentiary II ',
#  'Gilda (1946)': 'Gilda ',
#  "Carlito's Way (1993)": "Carlito's Way ",
#  'Henry V (1989)': 'Henry V ',
#  'Driving Miss Daisy (1989)': 'Driving Miss Daisy ',
#  'Eternity and a Day (Mia eoniotita ke mia mera ) (1998)': 'Eternity and a Day (Mia eoniotita ke mia mera ) ',
#  'Yankee Zulu (1994)': 'Yankee Zulu ',
#  '54 (1998)': '54 ',
#  'Big Trees, The (1952)': 'Big Trees, The ',
#  "Krippendorf's Tribe (1998)": "Krippendorf's Tribe ",
#  'Legend (1985)': 'Legend ',
#  'Star Trek: The Wrath of Khan (1982)': 'Star Trek: The Wrath of Khan ',
#  'Suicide Kings (1997)': 'Suicide Kings ',
#  'Shaggy D.A., The (1976)': 'Shaggy D.A., The ',
#  'Black Hole, The (1979)': 'Black Hole, The ',
#  'Dingo (1992)': 'Dingo ',
#  'Official Story, The (La Historia Oficial) (1985)': 'Official Story, The (La Historia Oficial) ',
#  'Room at the Top (1959)': 'Room at the Top ',
#  'Marked for Death (1990)': 'Marked for Death ',
#  'Great Expectations (1998)': 'Great Expectations ',
#  'Haunting, The (1963)': 'Haunting, The ',
#  'Dream With the Fishes (1997)': 'Dream With the Fishes ',
#  'Vermin (1998)': 'Vermin ',
#  'Gordy (1995)': 'Gordy ',
#  'Wishmaster (1997)': 'Wishmaster ',
#  'Office Space (1999)': 'Office Space ',
#  'Celtic Pride (1996)': 'Celtic Pride ',
#  'Choices (1981)': 'Choices ',
#  'Lost & Found (1999)': 'Lost & Found ',
#  'Sparrows (1926)': 'Sparrows ',
#  'Titus (1999)': 'Titus ',
#  'Fearless (1993)': 'Fearless ',
#  'One False Move (1991)': 'One False Move ',
#  'Grace of My Heart (1996)': 'Grace of My Heart ',
#  'Philadelphia (1993)': 'Philadelphia ',
#  'Gremlins 2: The New Batch (1990)': 'Gremlins 2: The New Batch ',
#  'To Sir with Love (1967)': 'To Sir with Love ',
#  'Solar Crisis (1993)': 'Solar Crisis ',
#  'Cement Garden, The (1993)': 'Cement Garden, The ',
#  'Fargo (1996)': 'Fargo ',
#  'Parenthood (1989)': 'Parenthood ',
#  'Glimmer Man, The (1996)': 'Glimmer Man, The ',
#  'Witness (1985)': 'Witness ',
#  'Picture Perfect (1997)': 'Picture Perfect ',
#  'Stage Fright (1950)': 'Stage Fright ',
#  'Arrival, The (1996)': 'Arrival, The ',
#  'Tea with Mussolini (1999)': 'Tea with Mussolini ',
#  'Gate II: Trespassers, The (1990)': 'Gate II: Trespassers, The ',
#  "Puppet Master III: Toulon's Revenge (1991)": "Puppet Master III: Toulon's Revenge ",
#  'Hoop Dreams (1994)': 'Hoop Dreams ',
#  'Brokedown Palace (1999)': 'Brokedown Palace ',
#  'Blues Brothers, The (1980)': 'Blues Brothers, The ',
#  'Flipper (1996)': 'Flipper ',
#  'Rich and Strange (1932)': 'Rich and Strange ',
#  'Hav Plenty (1997)': 'Hav Plenty ',
#  'Pitch Black (2000)': 'Pitch Black ',
#  'Mr. Death: The Rise and Fall of Fred A. Leuchter Jr. (1999)': 'Mr. Death: The Rise and Fall of Fred A. Leuchter Jr. ',
#  'Fallen (1998)': 'Fallen ',
#  'Scream (1996)': 'Scream ',
#  '28 Days (2000)': '28 Days ',
#  'Titanic (1953)': 'Titanic ',
#  'Lethal Weapon 2 (1989)': 'Lethal Weapon 2 ',
#  'Gung Ho (1986)': 'Gung Ho ',
#  'Pecker (1998)': 'Pecker ',
#  'Rising Sun (1993)': 'Rising Sun ',
#  'Othello (1995)': 'Othello ',
#  '2001: A Space Odyssey (1968)': '2001: A Space Odyssey ',
#  'Day of the Beast, The (El D�a de la bestia) (1995)': 'Day of the Beast, The (El D�a de la bestia) ',
#  'Platoon (1986)': 'Platoon ',
#  'Fatal Instinct (1993)': 'Fatal Instinct ',
#  'Last of the Mohicans, The (1992)': 'Last of the Mohicans, The ',
#  'Sunset Strip (2000)': 'Sunset Strip ',
#  'Beautiful (2000)': 'Beautiful ',
#  'Nightwatch (1997)': 'Nightwatch ',
#  'Mrs. Winterbourne (1996)': 'Mrs. Winterbourne ',
#  'Little Mermaid, The (1989)': 'Little Mermaid, The ',
#  'Glen or Glenda (1953)': 'Glen or Glenda ',
#  'Simple Plan, A (1998)': 'Simple Plan, A ',
#  'Twelfth Night (1996)': 'Twelfth Night ',
#  'Cape Fear (1991)': 'Cape Fear ',
#  'Oxygen (1999)': 'Oxygen ',
#  'Everest (1998)': 'Everest ',
#  'Phantasm (1979)': 'Phantasm ',
#  'Blue Angel, The (Blaue Engel, Der) (1930)': 'Blue Angel, The (Blaue Engel, Der) ',
#  'Gumby: The Movie (1995)': 'Gumby: The Movie ',
#  "Class of Nuke 'Em High (1986)": "Class of Nuke 'Em High ",
#  'Distinguished Gentleman, The (1992)': 'Distinguished Gentleman, The ',
#  'Blame It on Rio (1984)': 'Blame It on Rio ',
#  'Much Ado About Nothing (1993)': 'Much Ado About Nothing ',
#  'Headless Body in Topless Bar (1995)': 'Headless Body in Topless Bar ',
#  'Anguish (Angustia) (1986)': 'Anguish (Angustia) ',
#  'Tender Mercies (1983)': 'Tender Mercies ',
#  'European Vacation (1985)': 'European Vacation ',
#  "Peter's Friends (1992)": "Peter's Friends ",
#  "Breakfast at Tiffany's (1961)": "Breakfast at Tiffany's ",
#  'American Werewolf in Paris, An (1997)': 'American Werewolf in Paris, An ',
#  'Beetlejuice (1988)': 'Beetlejuice ',
#  'Mina Tannenbaum (1994)': 'Mina Tannenbaum ',
#  'Naturally Native (1998)': 'Naturally Native ',
#  'Cape Fear (1962)': 'Cape Fear ',
#  'Home Alone (1990)': 'Home Alone ',
#  'Wrong Man, The (1956)': 'Wrong Man, The ',
#  'From Dusk Till Dawn (1996)': 'From Dusk Till Dawn ',
#  'Character (Karakter) (1997)': 'Character (Karakter) ',
#  'Backbeat (1993)': 'Backbeat ',
#  'Moonraker (1979)': 'Moonraker ',
#  'Raven, The (1963)': 'Raven, The ',
#  'Threesome (1994)': 'Threesome ',
#  'U2: Rattle and Hum (1988)': 'U2: Rattle and Hum ',
#  'Babysitter, The (1995)': 'Babysitter, The ',
#  'My Own Private Idaho (1991)': 'My Own Private Idaho ',
#  'George of the Jungle (1997)': 'George of the Jungle ',
#  'Homage (1995)': 'Homage ',
#  'Indochine (1992)': 'Indochine ',
#  'South Park: Bigger, Longer and Uncut (1999)': 'South Park: Bigger, Longer and Uncut ',
#  'Brazil (1985)': 'Brazil ',
#  'Way We Were, The (1973)': 'Way We Were, The ',
#  'Shanghai Noon (2000)': 'Shanghai Noon ',
#  'Crocodile Dundee (1986)': 'Crocodile Dundee ',
#  'Five Wives, Three Secretaries and Me (1998)': 'Five Wives, Three Secretaries and Me ',
#  'Romeo Is Bleeding (1993)': 'Romeo Is Bleeding ',
#  'Great Dictator, The (1940)': 'Great Dictator, The ',
#  'Die Hard 2 (1990)': 'Die Hard 2 ',
#  'Brothers McMullen, The (1995)': 'Brothers McMullen, The ',
#  'Conceiving Ada (1997)': 'Conceiving Ada ',
#  'Goya in Bordeaux (Goya en Bodeos) (1999)': 'Goya in Bordeaux (Goya en Bodeos) ',
#  'Other Voices, Other Rooms (1997)': 'Other Voices, Other Rooms ',
#  'Brother from Another Planet, The (1984)': 'Brother from Another Planet, The ',
#  'Song of the South (1946)': 'Song of the South ',
#  'Funny Farm (1988)': 'Funny Farm ',
#  'Make Mine Music (1946)': 'Make Mine Music ',
#  'Velvet Goldmine (1998)': 'Velvet Goldmine ',
#  'Funeral, The (1996)': 'Funeral, The ',
#  'Bandits (1997)': 'Bandits ',
#  'Commitments, The (1991)': 'Commitments, The ',
#  "There's Something About Mary (1998)": "There's Something About Mary ",
#  'American in Paris, An (1951)': 'American in Paris, An ',
#  'Grease 2 (1982)': 'Grease 2 ',
#  'Like Water for Chocolate (Como agua para chocolate) (1992)': 'Like Water for Chocolate (Como agua para chocolate) ',
#  'I Went Down (1997)': 'I Went Down ',
#  'Tin Cup (1996)': 'Tin Cup ',
#  'Rosewood (1997)': 'Rosewood ',
#  'Wedding Singer, The (1998)': 'Wedding Singer, The ',
#  'Naked Gun 33 1/3: The Final Insult (1994)': 'Naked Gun 33 1/3: The Final Insult ',
#  'Copycat (1995)': 'Copycat ',
#  'Day the Earth Stood Still, The (1951)': 'Day the Earth Stood Still, The ',
#  'Son of the Sheik, The (1926)': 'Son of the Sheik, The ',
#  'Lamerica (1994)': 'Lamerica ',
#  'Romper Stomper (1992)': 'Romper Stomper ',
#  'Sheltering Sky, The (1990)': 'Sheltering Sky, The ',
#  'Inherit the Wind (1960)': 'Inherit the Wind ',
#  'Tex (1982)': 'Tex ',
#  'Dead Man Walking (1995)': 'Dead Man Walking ',
#  'King Kong (1976)': 'King Kong ',
#  'Daughters of the Dust (1992)': 'Daughters of the Dust ',
#  'Fried Green Tomatoes (1991)': 'Fried Green Tomatoes ',
#  'To Live (Huozhe) (1994)': 'To Live (Huozhe) ',
#  'Daytrippers, The (1996)': 'Daytrippers, The ',
#  'Some Kind of Wonderful (1987)': 'Some Kind of Wonderful ',
#  'Young Sherlock Holmes (1985)': 'Young Sherlock Holmes ',
#  'Postino, Il (The Postman) (1994)': 'Postino, Il (The Postman) ',
#  "Darby O'Gill and the Little People (1959)": "Darby O'Gill and the Little People ",
#  'Extreme Measures (1996)': 'Extreme Measures ',
#  'Crying Game, The (1992)': 'Crying Game, The ',
#  'JLG/JLG - autoportrait de d�cembre (1994)': 'JLG/JLG - autoportrait de d�cembre ',
#  'Ravenous (1999)': 'Ravenous ',
#  'Two Much (1996)': 'Two Much ',
#  'Mascara (1999)': 'Mascara ',
#  'Quest for Fire (1981)': 'Quest for Fire ',
#  'Hi-Lo Country, The (1998)': 'Hi-Lo Country, The ',
#  'Go Fish (1994)': 'Go Fish ',
#  'Casablanca (1942)': 'Casablanca ',
#  'Vampires (1998)': 'Vampires ',
#  'Savage Nights (Nuits fauves, Les) (1992)': 'Savage Nights (Nuits fauves, Les) ',
#  'Bambi (1942)': 'Bambi ',
#  'Affliction (1997)': 'Affliction ',
#  'Guilty as Sin (1993)': 'Guilty as Sin ',
#  'Convent, The (Convento, O) (1995)': 'Convent, The (Convento, O) ',
#  'Home Alone 2: Lost in New York (1992)': 'Home Alone 2: Lost in New York ',
#  'Scary Movie (2000)': 'Scary Movie ',
#  'Carnosaur (1993)': 'Carnosaur ',
#  'Drop Zone (1994)': 'Drop Zone ',
#  'Lodger, The (1926)': 'Lodger, The ',
#  'Telling Lies in America (1997)': 'Telling Lies in America ',
#  'Mr. & Mrs. Smith (1941)': 'Mr. & Mrs. Smith ',
#  'Alphaville (1965)': 'Alphaville ',
#  'High School High (1996)': 'High School High ',
#  'End of the Affair, The (1999)': 'End of the Affair, The ',
#  'Blood on the Sun (1945)': 'Blood on the Sun ',
#  'Soapdish (1991)': 'Soapdish ',
#  'Cross of Iron (1977)': 'Cross of Iron ',
#  'Addams Family Values (1993)': 'Addams Family Values ',
#  'Pet Sematary II (1992)': 'Pet Sematary II ',
#  'Mighty Peking Man (Hsing hsing wang) (1977)': 'Mighty Peking Man (Hsing hsing wang) ',
#  'Dead Again (1991)': 'Dead Again ',
#  'Cocoon (1985)': 'Cocoon ',
#  'Tango Lesson, The (1997)': 'Tango Lesson, The ',
#  'No Looking Back (1998)': 'No Looking Back ',
#  'Scrooged (1988)': 'Scrooged ',
#  'Man of No Importance, A (1994)': 'Man of No Importance, A ',
#  'Mask of Zorro, The (1998)': 'Mask of Zorro, The ',
#  'Barry Lyndon (1975)': 'Barry Lyndon ',
#  "Hang 'em High (1967)": "Hang 'em High ",
#  'Something to Talk About (1995)': 'Something to Talk About ',
#  'Our Town (1940)': 'Our Town ',
#  'Man and a Woman, A (Un Homme et une Femme) (1966)': 'Man and a Woman, A (Un Homme et une Femme) ',
#  'American Tail, An (1986)': 'American Tail, An ',
#  'Frances (1982)': 'Frances ',
#  'Harriet the Spy (1996)': 'Harriet the Spy ',
#  'Affair to Remember, An (1957)': 'Affair to Remember, An ',
#  "My Life and Times With Antonin Artaud (En compagnie d'Antonin Artaud) (1993)": "My Life and Times With Antonin Artaud (En compagnie d'Antonin Artaud) ",
#  'Boys Life 2 (1997)': 'Boys Life 2 ',
#  'Turtle Diary (1985)': 'Turtle Diary ',
#  'Great Mouse Detective, The (1986)': 'Great Mouse Detective, The ',
#  'Woman in Question, The (1950)': 'Woman in Question, The ',
#  'Bad Moon (1996)': 'Bad Moon ',
#  'High Plains Drifter (1972)': 'High Plains Drifter ',
#  'Jungle Book, The (1994)': 'Jungle Book, The ',
#  'Tao of Steve, The (2000)': 'Tao of Steve, The ',
#  'Maximum Overdrive (1986)': 'Maximum Overdrive ',
#  'Fight Club (1999)': 'Fight Club ',
#  'Bad Company (1995)': 'Bad Company ',
#  'Guys and Dolls (1955)': 'Guys and Dolls ',
#  'Slumber Party Massacre, The (1982)': 'Slumber Party Massacre, The ',
#  'Police Academy 3: Back in Training (1986)': 'Police Academy 3: Back in Training ',
#  "Wooden Man's Bride, The (Wu Kui) (1994)": "Wooden Man's Bride, The (Wu Kui) ",
#  'Coma (1978)': 'Coma ',
#  'Pet Sematary (1989)': 'Pet Sematary ',
#  "Don't Be a Menace to South Central While Drinking Your Juice in the Hood (1996)": "Don't Be a Menace to South Central While Drinking Your Juice in the Hood ",
#  'Soldier (1998)': 'Soldier ',
#  'Garbage Pail Kids Movie, The (1987)': 'Garbage Pail Kids Movie, The ',
#  'Under the Rainbow (1981)': 'Under the Rainbow ',
#  'Honeymoon in Vegas (1992)': 'Honeymoon in Vegas ',
#  'Man on the Moon (1999)': 'Man on the Moon ',
#  'Jules and Jim (Jules et Jim) (1961)': 'Jules and Jim (Jules et Jim) ',
#  'All Dogs Go to Heaven 2 (1996)': 'All Dogs Go to Heaven 2 ',
#  'Lock, Stock & Two Smoking Barrels (1998)': 'Lock, Stock & Two Smoking Barrels ',
#  'Max Dugan Returns (1983)': 'Max Dugan Returns ',
#  "Joe Gould's Secret (2000)": "Joe Gould's Secret ",
#  'N� (1998)': 'N� ',
#  'Superman (1978)': 'Superman ',
#  'Henry: Portrait of a Serial Killer (1990)': 'Henry: Portrait of a Serial Killer ',
#  'Parasite (1982)': 'Parasite ',
#  'Sleepy Hollow (1999)': 'Sleepy Hollow ',
#  'Juno and Paycock (1930)': 'Juno and Paycock ',
#  'Children of the Corn III (1994)': 'Children of the Corn III ',
#  'American Movie (1999)': 'American Movie ',
#  "Gridlock'd (1997)": "Gridlock'd ",
#  'Goodbye, Lover (1999)': 'Goodbye, Lover ',
#  'Prince of the City (1981)': 'Prince of the City ',
#  'Big Lebowski, The (1998)': 'Big Lebowski, The ',
#  'Dear Jesse (1997)': 'Dear Jesse ',
#  'Leading Man, The (1996)': 'Leading Man, The ',
#  'Spartacus (1960)': 'Spartacus ',
#  'Hanging Up (2000)': 'Hanging Up ',
#  'Shall We Dance? (1937)': 'Shall We Dance? ',
#  'Of Human Bondage (1934)': 'Of Human Bondage ',
#  'Palm Beach Story, The (1942)': 'Palm Beach Story, The ',
#  'Tumbleweeds (1999)': 'Tumbleweeds ',
#  'Vanya on 42nd Street (1994)': 'Vanya on 42nd Street ',
#  'Eraserhead (1977)': 'Eraserhead ',
#  'Hoosiers (1986)': 'Hoosiers ',
#  'Live and Let Die (1973)': 'Live and Let Die ',
#  'Flubber (1997)': 'Flubber ',
#  'Englishman Who Went Up a Hill, But Came Down a Mountain, The (1995)': 'Englishman Who Went Up a Hill, But Came Down a Mountain, The ',
#  'Firewalker (1986)': 'Firewalker ',
#  'Heidi Fleiss: Hollywood Madam (1995)': 'Heidi Fleiss: Hollywood Madam ',
#  'Alaska (1996)': 'Alaska ',
#  'Mortal Thoughts (1991)': 'Mortal Thoughts ',
#  'Belle de jour (1967)': 'Belle de jour ',
#  'Herbie Goes to Monte Carlo (1977)': 'Herbie Goes to Monte Carlo ',
#  'Nineteen Eighty-Four (1984)': 'Nineteen Eighty-Four ',
#  'Papillon (1973)': 'Papillon ',
#  'Arachnophobia (1990)': 'Arachnophobia ',
#  'Multiplicity (1996)': 'Multiplicity ',
#  'Suddenly, Last Summer (1959)': 'Suddenly, Last Summer ',
#  'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)': 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb ',
#  'Two Thousand Maniacs! (1964)': 'Two Thousand Maniacs! ',
#  'Knockout (1999)': 'Knockout ',
#  "She's Gotta Have It (1986)": "She's Gotta Have It ",
#  'Murder in the First (1995)': 'Murder in the First ',
#  'Falling in Love Again (1980)': 'Falling in Love Again ',
#  'Peter Pan (1953)': 'Peter Pan ',
#  'Stand and Deliver (1987)': 'Stand and Deliver ',
#  'Journey of August King, The (1995)': 'Journey of August King, The ',
#  'Piano, The (1993)': 'Piano, The ',
#  'Tom & Viv (1994)': 'Tom & Viv ',
#  'Innocents, The (1961)': 'Innocents, The ',
#  'MURDER and murder (1996)': 'MURDER and murder ',
#  'Babes in Toyland (1961)': 'Babes in Toyland ',
#  'Golden Earrings (1947)': 'Golden Earrings ',
#  'Hard Rain (1998)': 'Hard Rain ',
#  'Kika (1993)': 'Kika ',
#  'Bird on a Wire (1990)': 'Bird on a Wire ',
#  'Princess Caraboo (1994)': 'Princess Caraboo ',
#  'Primal Fear (1996)': 'Primal Fear ',
#  'Some Folks Call It a Sling Blade (1993)': 'Some Folks Call It a Sling Blade ',
#  'American Tail: Fievel Goes West, An (1991)': 'American Tail: Fievel Goes West, An ',
#  'Deliverance (1972)': 'Deliverance ',
#  'Black Sheep (1996)': 'Black Sheep ',
#  'Nikita (La Femme Nikita) (1990)': 'Nikita (La Femme Nikita) ',
#  'How to Be a Player (1997)': 'How to Be a Player ',
#  'Mediterraneo (1991)': 'Mediterraneo ',
#  'From Here to Eternity (1953)': 'From Here to Eternity ',
#  'Body Snatcher, The (1945)': 'Body Snatcher, The ',
#  'Ref, The (1994)': 'Ref, The ',
#  'In the Line of Duty 2 (1987)': 'In the Line of Duty 2 ',
#  'Substance of Fire, The (1996)': 'Substance of Fire, The ',
#  'Klute (1971)': 'Klute ',
#  'East Palace West Palace (Dong gong xi gong) (1997)': 'East Palace West Palace (Dong gong xi gong) ',
#  "My Boyfriend's Back (1993)": "My Boyfriend's Back ",
#  'Never Met Picasso (1996)': 'Never Met Picasso ',
#  'Ordinary People (1980)': 'Ordinary People ',
#  'Breakfast Club, The (1985)': 'Breakfast Club, The ',
#  'Violets Are Blue... (1986)': 'Violets Are Blue... ',
#  'Heavy (1995)': 'Heavy ',
#  'All That Jazz (1979)': 'All That Jazz ',
#  'Giant (1956)': 'Giant ',
#  "Bram Stoker's Dracula (1992)": "Bram Stoker's Dracula ",
#  'Pompatus of Love, The (1996)': 'Pompatus of Love, The ',
#  'Bats (1999)': 'Bats ',
#  'Love & Sex (2000)': 'Love & Sex ',
#  'Mystery, Alaska (1999)': 'Mystery, Alaska ',
#  'Bone Collector, The (1999)': 'Bone Collector, The ',
#  'Shaft in Africa (1973)': 'Shaft in Africa ',
#  'Stanley & Iris (1990)': 'Stanley & Iris ',
#  'Hana-bi (1997)': 'Hana-bi ',
#  '24 7: Twenty Four Seven (1997)': '24 7: Twenty Four Seven ',
#  'Red Violin, The (Le Violon rouge) (1998)': 'Red Violin, The (Le Violon rouge) ',
#  'Losing Isaiah (1995)': 'Losing Isaiah ',
#  'Flirting With Disaster (1996)': 'Flirting With Disaster ',
#  'Buddy (1997)': 'Buddy ',
#  'Kicking and Screaming (1995)': 'Kicking and Screaming ',
#  'Suture (1993)': 'Suture ',
#  'Last Action Hero (1993)': 'Last Action Hero ',
#  'Fan, The (1996)': 'Fan, The ',
#  'American Buffalo (1996)': 'American Buffalo ',
#  'Homegrown (1998)': 'Homegrown ',
#  'Navigator: A Mediaeval Odyssey, The (1988)': 'Navigator: A Mediaeval Odyssey, The ',
#  'Poltergeist (1982)': 'Poltergeist ',
#  'Seven Days in May (1964)': 'Seven Days in May ',
#  'Funhouse, The (1981)': 'Funhouse, The ',
#  'Oscar and Lucinda (a.k.a. Oscar & Lucinda) (1997)': 'Oscar and Lucinda (a.k.a. Oscar & Lucinda) ',
#  'Rain (1932)': 'Rain ',
#  'Doors, The (1991)': 'Doors, The ',
#  'Best Years of Our Lives, The (1946)': 'Best Years of Our Lives, The ',
#  "Child's Play 3 (1992)": "Child's Play 3 ",
#  "Brother's Kiss, A (1997)": "Brother's Kiss, A ",
#  'Lovers of the Arctic Circle, The (Los Amantes del C�rculo Polar) (1998)': 'Lovers of the Arctic Circle, The (Los Amantes del C�rculo Polar) ',
#  'Three Seasons (1999)': 'Three Seasons ',
#  'Problem Child 2 (1991)': 'Problem Child 2 ',
#  'Twilight (1998)': 'Twilight ',
#  'Hellhounds on My Trail (1999)': 'Hellhounds on My Trail ',
#  'Midnight Cowboy (1969)': 'Midnight Cowboy ',
#  "Boricua's Bond (2000)": "Boricua's Bond ",
#  'Unzipped (1995)': 'Unzipped ',
#  'Village of the Damned (1995)': 'Village of the Damned ',
#  'Walk in the Clouds, A (1995)': 'Walk in the Clouds, A ',
#  'Hillbillys in a Haunted House (1967)': 'Hillbillys in a Haunted House ',
#  "Killer's Kiss (1955)": "Killer's Kiss ",
#  'Pump Up the Volume (1990)': 'Pump Up the Volume ',
#  'Something for Everyone (1970)': 'Something for Everyone ',
#  '1-900 (1994)': '1-900 ',
#  'Avengers, The (1998)': 'Avengers, The ',
#  'Hands on a Hard Body (1996)': 'Hands on a Hard Body ',
#  'To Wong Foo, Thanks for Everything! Julie Newmar (1995)': 'To Wong Foo, Thanks for Everything! Julie Newmar ',
#  'With Byrd at the South Pole (1930)': 'With Byrd at the South Pole ',
#  'Great Escape, The (1963)': 'Great Escape, The ',
#  'Queen Margot (La Reine Margot) (1994)': 'Queen Margot (La Reine Margot) ',
#  'Acid House, The (1998)': 'Acid House, The ',
#  'Solas (1999)': 'Solas ',
#  'Holy Man (1998)': 'Holy Man ',
#  'Courage Under Fire (1996)': 'Courage Under Fire ',
#  "Amityville 1992: It's About Time (1992)": "Amityville 1992: It's About Time ",
#  'Judy Berlin (1999)': 'Judy Berlin ',
#  'Groundhog Day (1993)': 'Groundhog Day ',
#  'U.S. Marshalls (1998)': 'U.S. Marshalls ',
#  'Crimes of the Heart (1986)': 'Crimes of the Heart ',
#  "Porky's Revenge (1985)": "Porky's Revenge ",
#  'Opportunists, The (1999)': 'Opportunists, The ',
#  'Sadness of Sex, The (1995)': 'Sadness of Sex, The ',
#  'Good Earth, The (1937)': 'Good Earth, The ',
#  'Howling, The (1980)': 'Howling, The ',
#  'Quiet Man, The (1952)': 'Quiet Man, The ',
#  'Masque of the Red Death, The (1964)': 'Masque of the Red Death, The ',
#  'Whatever It Takes (2000)': 'Whatever It Takes ',
#  'Relative Fear (1994)': 'Relative Fear ',
#  'I, Worst of All (Yo, la peor de todas) (1990)': 'I, Worst of All (Yo, la peor de todas) ',
#  'Body Shots (1999)': 'Body Shots ',
#  'Promise, The (Versprechen, Das) (1994)': 'Promise, The (Versprechen, Das) ',
#  'Election (1999)': 'Election ',
#  'Hitch-Hiker, The (1953)': 'Hitch-Hiker, The ',
#  'Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)': 'Sunset Blvd. (a.k.a. Sunset Boulevard) ',
#  "Pete's Dragon (1977)": "Pete's Dragon ",
#  'Borrowers, The (1997)': 'Borrowers, The ',
#  'Akira (1988)': 'Akira ',
#  "City Slickers II: The Legend of Curly's Gold (1994)": "City Slickers II: The Legend of Curly's Gold ",
#  'Picnic (1955)': 'Picnic ',
#  'Secret Agent (1936)': 'Secret Agent ',
#  'Footloose (1984)': 'Footloose ',
#  'Jeremiah Johnson (1972)': 'Jeremiah Johnson ',
#  'Alice in Wonderland (1951)': 'Alice in Wonderland ',
#  'Sommersby (1993)': 'Sommersby ',
#  'Gattaca (1997)': 'Gattaca ',
#  'Thelma & Louise (1991)': 'Thelma & Louise ',
#  'Payback (1999)': 'Payback ',
#  'Robin Hood (1973)': 'Robin Hood ',
#  'Where Eagles Dare (1969)': 'Where Eagles Dare ',
#  'Hud (1963)': 'Hud ',
#  'Bronco Billy (1980)': 'Bronco Billy ',
#  'Bonheur, Le (1965)': 'Bonheur, Le ',
#  'Foolish (1999)': 'Foolish ',
#  'Carrington (1995)': 'Carrington ',
#  'Mis�rables, Les (1995)': 'Mis�rables, Les ',
#  'Searching for Bobby Fischer (1993)': 'Searching for Bobby Fischer ',
#  'Low Life, The (1994)': 'Low Life, The ',
#  'Shop Around the Corner, The (1940)': 'Shop Around the Corner, The ',
#  'Frenzy (1972)': 'Frenzy ',
#  'Kiss of Death (1995)': 'Kiss of Death ',
#  '10 Things I Hate About You (1999)': '10 Things I Hate About You ',
#  'Snowriders (1996)': 'Snowriders ',
#  'Friday (1995)': 'Friday ',
#  'Mr. Magoo (1997)': 'Mr. Magoo ',
#  'Chambermaid on the Titanic, The (1998)': 'Chambermaid on the Titanic, The ',
#  'Cimarron (1931)': 'Cimarron ',
#  'Aces: Iron Eagle III (1992)': 'Aces: Iron Eagle III ',
#  'All Dogs Go to Heaven (1989)': 'All Dogs Go to Heaven ',
#  'Black Tights (Les Collants Noirs) (1960)': 'Black Tights (Les Collants Noirs) ',
#  'Creepshow 2 (1987)': 'Creepshow 2 ',
#  'Day the Sun Turned Cold, The (Tianguo niezi) (1994)': 'Day the Sun Turned Cold, The (Tianguo niezi) ',
#  'Stag (1997)': 'Stag ',
#  'Sex, Lies, and Videotape (1989)': 'Sex, Lies, and Videotape ',
#  'Son of Frankenstein (1939)': 'Son of Frankenstein ',
#  'Adventures of Sebastian Cole, The (1998)': 'Adventures of Sebastian Cole, The ',
#  'Queens Logic (1991)': 'Queens Logic ',
#  'Broken Arrow (1996)': 'Broken Arrow ',
#  'Desert Winds (1995)': 'Desert Winds ',
#  "Sophie's Choice (1982)": "Sophie's Choice ",
#  'X-Files: Fight the Future, The (1998)': 'X-Files: Fight the Future, The ',
#  'King of Marvin Gardens, The (1972)': 'King of Marvin Gardens, The ',
#  'Hero (1992)': 'Hero ',
#  'Hell Night (1981)': 'Hell Night ',
#  'Andre (1994)': 'Andre ',
#  'Passion Fish (1992)': 'Passion Fish ',
#  'Simple Twist of Fate, A (1994)': 'Simple Twist of Fate, A ',
#  'Get Shorty (1995)': 'Get Shorty ',
#  'Batman Returns (1992)': 'Batman Returns ',
#  'Walk on the Moon, A (1999)': 'Walk on the Moon, A ',
#  'Nights of Cabiria (Le Notti di Cabiria) (1957)': 'Nights of Cabiria (Le Notti di Cabiria) ',
#  'Best of the Best 3: No Turning Back (1995)': 'Best of the Best 3: No Turning Back ',
#  'Cry, the Beloved Country (1995)': 'Cry, the Beloved Country ',
#  'Swing Kids (1993)': 'Swing Kids ',
#  '2010 (1984)': '2010 ',
#  'Thomas Crown Affair, The (1999)': 'Thomas Crown Affair, The ',
#  'Friends & Lovers (1999)': 'Friends & Lovers ',
#  'No Small Affair (1984)': 'No Small Affair ',
#  'Mrs. Doubtfire (1993)': 'Mrs. Doubtfire ',
#  'See the Sea (Regarde la mer) (1997)': 'See the Sea (Regarde la mer) ',
#  'Slaughterhouse (1987)': 'Slaughterhouse ',
#  'Awakenings (1990)': 'Awakenings ',
#  'Hype! (1996)': 'Hype! ',
#  'Swimming with Sharks (1995)': 'Swimming with Sharks ',
#  'Karate Kid, The (1984)': 'Karate Kid, The ',
#  'Dracula (1958)': 'Dracula ',
#  'Reluctant Debutante, The (1958)': 'Reluctant Debutante, The ',
#  'Murder, My Sweet (1944)': 'Murder, My Sweet ',
#  'Sweet Nothing (1995)': 'Sweet Nothing ',
#  'Office Killer (1997)': 'Office Killer ',
#  'Deuce Bigalow: Male Gigolo (1999)': 'Deuce Bigalow: Male Gigolo ',
#  'Ladyhawke (1985)': 'Ladyhawke ',
#  'Shanghai Triad (Yao a yao yao dao waipo qiao) (1995)': 'Shanghai Triad (Yao a yao yao dao waipo qiao) ',
#  'Love! Valour! Compassion! (1997)': 'Love! Valour! Compassion! ',
#  'Blue Sky (1994)': 'Blue Sky ',
#  'Get Carter (2000)': 'Get Carter ',
#  'Cider House Rules, The (1999)': 'Cider House Rules, The ',
#  'I Married A Strange Person (1997)': 'I Married A Strange Person ',
#  'Peeping Tom (1960)': 'Peeping Tom ',
#  'Governess, The (1998)': 'Governess, The ',
#  'Jefferson in Paris (1995)': 'Jefferson in Paris ',
#  'Drunks (1997)': 'Drunks ',
#  'It Came from Outer Space (1953)': 'It Came from Outer Space ',
#  'Black Cat, White Cat (Crna macka, beli macor) (1998)': 'Black Cat, White Cat (Crna macka, beli macor) ',
#  'Inferno (1980)': 'Inferno ',
#  'White Balloon, The (Badkonake Sefid ) (1995)': 'White Balloon, The (Badkonake Sefid ) ',
#  'Jingle All the Way (1996)': 'Jingle All the Way ',
#  'Maximum Risk (1996)': 'Maximum Risk ',
#  "Kestrel's Eye (Falkens �ga) (1998)": "Kestrel's Eye (Falkens �ga) ",
#  'Bed of Roses (1996)': 'Bed of Roses ',
#  'Stay Tuned (1992)': 'Stay Tuned ',
#  '8 1/2 Women (1999)': '8 1/2 Women ',
#  'Native Son (1986)': 'Native Son ',
#  'Time of the Gypsies (Dom za vesanje) (1989)': 'Time of the Gypsies (Dom za vesanje) ',
#  'Master Ninja I (1984)': 'Master Ninja I ',
#  'Last Resort (1994)': 'Last Resort ',
#  'Federal Hill (1994)': 'Federal Hill ',
#  'Singles (1992)': 'Singles ',
#  'Butcher Boy, The (1998)': 'Butcher Boy, The ',
#  'Double Happiness (1994)': 'Double Happiness ',
#  'Psycho III (1986)': 'Psycho III ',
#  'Interview with the Vampire (1994)': 'Interview with the Vampire ',
#  'Man in the Iron Mask, The (1998)': 'Man in the Iron Mask, The ',
#  'Jeanne and the Perfect Guy (Jeanne et le gar�on formidable) (1998)': 'Jeanne and the Perfect Guy (Jeanne et le gar�on formidable) ',
#  'Guardian Angel (1994)': 'Guardian Angel ',
#  'Earth Vs. the Flying Saucers (1956)': 'Earth Vs. the Flying Saucers ',
#  'Trial, The (Le Proc�s) (1963)': 'Trial, The (Le Proc�s) ',
#  'Small Time Crooks (2000)': 'Small Time Crooks ',
#  'Rumble in the Bronx (1995)': 'Rumble in the Bronx ',
#  'Hangmen Also Die (1943)': 'Hangmen Also Die ',
#  'Slaves to the Underground (1997)': 'Slaves to the Underground ',
#  'Champagne (1928)': 'Champagne ',
#  'Farmer & Chase (1995)': 'Farmer & Chase ',
#  'Goonies, The (1985)': 'Goonies, The ',
#  'Phantasm III: Lord of the Dead (1994)': 'Phantasm III: Lord of the Dead ',
#  'Burnt By the Sun (Utomlyonnye solntsem) (1994)': 'Burnt By the Sun (Utomlyonnye solntsem) ',
#  "Nobody's Fool (1994)": "Nobody's Fool ",
#  'Man Who Knew Too Much, The (1956)': 'Man Who Knew Too Much, The ',
#  'Torn Curtain (1966)': 'Torn Curtain ',
#  'Still Crazy (1998)': 'Still Crazy ',
#  'Cabin Boy (1994)': 'Cabin Boy ',
#  'Death in Brunswick (1991)': 'Death in Brunswick ',
#  'Boiling Point (1993)': 'Boiling Point ',
#  'Snake Eyes (1998)': 'Snake Eyes ',
#  "On Her Majesty's Secret Service (1969)": "On Her Majesty's Secret Service ",
#  'Amadeus (1984)': 'Amadeus ',
#  'Wag the Dog (1997)': 'Wag the Dog ',
#  'Almost Heroes (1998)': 'Almost Heroes ',
#  'Transformers: The Movie, The (1986)': 'Transformers: The Movie, The ',
#  'Indiana Jones and the Temple of Doom (1984)': 'Indiana Jones and the Temple of Doom ',
#  'Sarafina! (1992)': 'Sarafina! ',
#  'Steal This Movie! (2000)': 'Steal This Movie! ',
#  'Cop Land (1997)': 'Cop Land ',
#  'Breakdown (1997)': 'Breakdown ',
#  'Bridge at Remagen, The (1969)': 'Bridge at Remagen, The ',
#  'Playing God (1997)': 'Playing God ',
#  'Tokyo Fist (1995)': 'Tokyo Fist ',
#  'Pagemaster, The (1994)': 'Pagemaster, The ',
#  'Five Easy Pieces (1970)': 'Five Easy Pieces ',
#  'Battleship Potemkin, The (Bronenosets Potyomkin) (1925)': 'Battleship Potemkin, The (Bronenosets Potyomkin) ',
#  'Prefontaine (1997)': 'Prefontaine ',
#  'My Dog Skip (1999)': 'My Dog Skip ',
#  'Santa Fe Trail (1940)': 'Santa Fe Trail ',
#  'Raging Bull (1980)': 'Raging Bull ',
#  'Plenty (1985)': 'Plenty ',
#  'Vegas Vacation (1997)': 'Vegas Vacation ',
#  'Glass Shield, The (1994)': 'Glass Shield, The ',
#  'True Grit (1969)': 'True Grit ',
#  'House Arrest (1996)': 'House Arrest ',
#  'Friday the 13th Part VI: Jason Lives (1986)': 'Friday the 13th Part VI: Jason Lives ',
#  'Very Natural Thing, A (1974)': 'Very Natural Thing, A ',
#  'Before and After (1996)': 'Before and After ',
#  'Tough and Deadly (1995)': 'Tough and Deadly ',
#  "One Flew Over the Cuckoo's Nest (1975)": "One Flew Over the Cuckoo's Nest ",
#  'Jaws (1975)': 'Jaws ',
#  'Tingler, The (1959)': 'Tingler, The ',
#  'Plutonium Circus (1995)': 'Plutonium Circus ',
#  'Winter Guest, The (1997)': 'Winter Guest, The ',
#  "Cookie's Fortune (1999)": "Cookie's Fortune ",
#  'Rear Window (1954)': 'Rear Window ',
#  'Eat Drink Man Woman (1994)': 'Eat Drink Man Woman ',
#  'Homeward Bound II: Lost in San Francisco (1996)': 'Homeward Bound II: Lost in San Francisco ',
#  'Desert Bloom (1986)': 'Desert Bloom ',
#  'Pocahontas (1995)': 'Pocahontas ',
#  'Balto (1995)': 'Balto ',
#  'Dying Young (1991)': 'Dying Young ',
#  'Decline of Western Civilization Part II: The Metal Years, The (1988)': 'Decline of Western Civilization Part II: The Metal Years, The ',
#  'Police Story 4: Project S (Chao ji ji hua) (1993)': 'Police Story 4: Project S (Chao ji ji hua) ',
#  'Iron Eagle II (1988)': 'Iron Eagle II ',
#  'Digging to China (1998)': 'Digging to China ',
#  'Fantastic Planet, The (La Plan�te sauvage) (1973)': 'Fantastic Planet, The (La Plan�te sauvage) ',
#  'Star Trek: The Motion Picture (1979)': 'Star Trek: The Motion Picture ',
#  'Love Jones (1997)': 'Love Jones ',
#  'Amityville: Dollhouse (1996)': 'Amityville: Dollhouse ',
#  'Bull Durham (1988)': 'Bull Durham ',
#  'Star Trek IV: The Voyage Home (1986)': 'Star Trek IV: The Voyage Home ',
#  'No Way Out (1987)': 'No Way Out ',
#  'Star Trek III: The Search for Spock (1984)': 'Star Trek III: The Search for Spock ',
#  'Swiss Family Robinson (1960)': 'Swiss Family Robinson ',
#  'Sabotage (1936)': 'Sabotage ',
#  'Zero Effect (1998)': 'Zero Effect ',
#  'Super Mario Bros. (1993)': 'Super Mario Bros. ',
#  'Perfect Blue (1997)': 'Perfect Blue ',
#  '7th Voyage of Sinbad, The (1958)': '7th Voyage of Sinbad, The ',
#  'Species II (1998)': 'Species II ',
#  "Big Momma's House (2000)": "Big Momma's House ",
#  "Bug's Life, A (1998)": "Bug's Life, A ",
#  'Class Reunion (1982)': 'Class Reunion ',
#  'Gendernauts (1999)': 'Gendernauts ',
#  'Real Blonde, The (1997)': 'Real Blonde, The ',
#  'Airplane! (1980)': 'Airplane! ',
#  'Money Talks (1997)': 'Money Talks ',
#  'Young Frankenstein (1974)': 'Young Frankenstein ',
#  'Nadja (1994)': 'Nadja ',
#  'Lake Placid (1999)': 'Lake Placid ',
#  'Sugar Town (1999)': 'Sugar Town ',
#  'Nothing to Lose (1994)': 'Nothing to Lose ',
#  'Seventh Sign, The (1988)': 'Seventh Sign, The ',
#  'Raisin in the Sun, A (1961)': 'Raisin in the Sun, A ',
#  "Rich Man's Wife, The (1996)": "Rich Man's Wife, The ",
#  'Alley Cats, The (1968)': 'Alley Cats, The ',
#  'Mad Max Beyond Thunderdome (1985)': 'Mad Max Beyond Thunderdome ',
#  'Nobody Loves Me (Keiner liebt mich) (1994)': 'Nobody Loves Me (Keiner liebt mich) ',
#  'How Stella Got Her Groove Back (1998)': 'How Stella Got Her Groove Back ',
#  'British Intelligence (1940)': 'British Intelligence ',
#  'Leopard Son, The (1996)': 'Leopard Son, The ',
#  'Brighton Beach Memoirs (1986)': 'Brighton Beach Memoirs ',
#  'Striptease (1996)': 'Striptease ',
#  'Baton Rouge (1988)': 'Baton Rouge ',
#  'Black Dog (1998)': 'Black Dog ',
#  'Dog Day Afternoon (1975)': 'Dog Day Afternoon ',
#  'Lords of Flatbush, The (1974)': 'Lords of Flatbush, The ',
#  'Hellbound: Hellraiser II (1988)': 'Hellbound: Hellraiser II ',
#  'Batman Forever (1995)': 'Batman Forever ',
#  'Venice/Venice (1992)': 'Venice/Venice ',
#  'French Twist (Gazon maudit) (1995)': 'French Twist (Gazon maudit) ',
#  'Jar, The (Khomreh) (1992)': 'Jar, The (Khomreh) ',
#  'Tall Tale (1994)': 'Tall Tale ',
#  'Scarlet Letter, The (1926)': 'Scarlet Letter, The ',
#  'Mr. Jones (1993)': 'Mr. Jones ',
#  'Big Bully (1996)': 'Big Bully ',
#  'Stonewall (1995)': 'Stonewall ',
#  'Wedding Gift, The (1994)': 'Wedding Gift, The ',
#  'Friend of the Deceased, A (1997)': 'Friend of the Deceased, A ',
#  'Wallace & Gromit: The Best of Aardman Animation (1996)': 'Wallace & Gromit: The Best of Aardman Animation ',
#  'Buffy the Vampire Slayer (1992)': 'Buffy the Vampire Slayer ',
#  'Dracula (1931)': 'Dracula ',
#  'Othello (1952)': 'Othello ',
#  'Around the World in 80 Days (1956)': 'Around the World in 80 Days ',
#  'Black Sabbath (Tre Volti Della Paura, I) (1963)': 'Black Sabbath (Tre Volti Della Paura, I) ',
#  'Metropolis (1926)': 'Metropolis ',
#  'Night Porter, The (Il Portiere di notte) (1974)': 'Night Porter, The (Il Portiere di notte) ',
#  'Beyond the Mat (2000)': 'Beyond the Mat ',
#  'Crucible, The (1996)': 'Crucible, The ',
#  'Great Ziegfeld, The (1936)': 'Great Ziegfeld, The ',
#  "Ulee's Gold (1997)": "Ulee's Gold ",
#  'Ten Benny (1997)': 'Ten Benny ',
#  'Message in a Bottle (1999)': 'Message in a Bottle ',
#  'Mirror, The (Zerkalo) (1975)': 'Mirror, The (Zerkalo) ',
#  'Clockwatchers (1997)': 'Clockwatchers ',
#  'Game, The (1997)': 'Game, The ',
#  'Psycho (1960)': 'Psycho ',
#  'Career Girls (1997)': 'Career Girls ',
#  'Clean Slate (Coup de Torchon) (1981)': 'Clean Slate (Coup de Torchon) ',
#  'Six Days Seven Nights (1998)': 'Six Days Seven Nights ',
#  'Last Supper, The (1995)': 'Last Supper, The ',
#  'Meatballs 4 (1992)': 'Meatballs 4 ',
#  'Umbrellas of Cherbourg, The (Parapluies de Cherbourg, Les) (1964)': 'Umbrellas of Cherbourg, The (Parapluies de Cherbourg, Les) ',
#  'Walkabout (1971)': 'Walkabout ',
#  'Clerks (1994)': 'Clerks ',
#  'Ronin (1998)': 'Ronin ',
#  'Sound of Music, The (1965)': 'Sound of Music, The ',
#  'Tarzan the Fearless (1933)': 'Tarzan the Fearless ',
#  'Spanking the Monkey (1994)': 'Spanking the Monkey ',
#  'Hope Floats (1998)': 'Hope Floats ',
#  'Outlaw, The (1943)': 'Outlaw, The ',
#  'Psycho (1998)': 'Psycho ',
#  'Licence to Kill (1989)': 'Licence to Kill ',
#  'Mumford (1999)': 'Mumford ',
#  'Lethal Weapon 3 (1992)': 'Lethal Weapon 3 ',
#  'Anna Karenina (1997)': 'Anna Karenina ',
#  'Grandview, U.S.A. (1984)': 'Grandview, U.S.A. ',
#  'Back to School (1986)': 'Back to School ',
#  'Johnny 100 Pesos (1993)': 'Johnny 100 Pesos ',
#  'Sixteen Candles (1984)': 'Sixteen Candles ',
#  'My Fair Lady (1964)': 'My Fair Lady ',
#  'Women on the Verge of a Nervous Breakdown (1988)': 'Women on the Verge of a Nervous Breakdown ',
#  'Goodbye, 20th Century (Zbogum na dvadesetiot vek) (1998)': 'Goodbye, 20th Century (Zbogum na dvadesetiot vek) ',
#  'Exorcist III, The (1990)': 'Exorcist III, The ',
#  'Emma (1996)': 'Emma ',
#  'McCullochs, The (1975)': 'McCullochs, The ',
#  'Quatermass and the Pit (1967)': 'Quatermass and the Pit ',
#  'Rebel Without a Cause (1955)': 'Rebel Without a Cause ',
#  ...}

# %%
#电影类型转数字字典
genres_set = set()
for item in movies['Genres'].str.split('|'):
    genres_set.update(item)

genres_set.add('<PAD>')
genres2int = {item:index for index,item in enumerate(genres_set)}

# %%
genres2int
# Out:
# {'<PAD>': 8,
#  'Action': 2,
#  'Adventure': 1,
#  'Animation': 11,
#  "Children's": 15,
#  'Comedy': 6,
#  'Crime': 12,
#  'Documentary': 10,
#  'Drama': 9,
#  'Fantasy': 0,
#  'Film-Noir': 5,
#  'Horror': 4,
#  'Musical': 14,
#  'Mystery': 7,
#  'Romance': 17,
#  'Sci-Fi': 18,
#  'Thriller': 3,
#  'War': 16,
#  'Western': 13}

# %%
#将电影类型转成等长数字列表，长度是18
genres_map = {item:[genres2int[row] for row in item.split('|')] for index,item in enumerate(set(movies['Genres']))}

for key in genres_map:
    for cnt in range(max(genres2int.values()) - len(genres_map[key])):
        genres_map[key].insert(len(genres_map[key]) + cnt,genres2int['<PAD>'])

movies['Genres'] = movies['Genres'].map(genres_map)

# %%
#电影Title转数字字典
title_set = set()
for val in movies['Title'].str.split():
    title_set.update(val)

title_set.add('<PAD>')
title2int = {val:ii for ii, val in enumerate(title_set)}

# %%
title2int
# Out:
# {'Check': 0,
#  'May': 1,
#  'Crocodile': 2,
#  'Apart': 3,
#  '60': 4,
#  'pastorale,': 5,
#  'Avengers,': 6,
#  'de': 7,
#  'k�ldum': 8,
#  '(Et': 9,
#  'Lian)': 10,
#  'Mating': 11,
#  'Total': 12,
#  'Greenwich': 13,
#  'Cuts': 14,
#  '(Saimt': 15,
#  'Trip': 16,
#  'Valiant': 17,
#  'Cold': 18,
#  'Chungking': 19,
#  'Harriet': 20,
#  'Storm,': 21,
#  'Whatever': 22,
#  'Behavior': 23,
#  'Stop': 24,
#  "Cat's": 25,
#  'Pajama': 26,
#  'Strikes': 27,
#  'Team': 28,
#  'Case,': 29,
#  'Extremities': 30,
#  'Sacrifice': 31,
#  'Shane': 32,
#  "Farmer's": 33,
#  'Morning': 34,
#  'Douce': 35,
#  'Uninvited': 36,
#  'Odyssey,': 37,
#  'Enterprise': 38,
#  '(Rosso': 39,
#  'Dazed': 40,
#  'Roma': 41,
#  "Pete's": 42,
#  'Couple,': 43,
#  'Cider': 44,
#  'Angela': 45,
#  'Dollhouse': 46,
#  'Drugstore': 47,
#  'Committed': 48,
#  'Ross': 49,
#  'Gun,': 50,
#  '3-D': 51,
#  'Making': 52,
#  "McHale's": 53,
#  'Grape': 54,
#  'Two': 55,
#  'Secreto)': 56,
#  'Maybe,': 57,
#  'Tombstone': 58,
#  'Sexual': 59,
#  'Honey,': 60,
#  'Lifeboat': 61,
#  'Steam:': 62,
#  'Soft': 63,
#  'Guess': 64,
#  'Brother,': 65,
#  'China': 66,
#  'Person': 67,
#  'Judge': 68,
#  'Business': 69,
#  'Anywhere': 70,
#  'Urbania': 71,
#  'Jimmy,': 72,
#  'Wonderful,': 73,
#  'Wanted:': 74,
#  'Ferox)': 75,
#  'Mat': 76,
#  'Happy': 77,
#  'Revolution,': 78,
#  'Trek:': 79,
#  'Wives': 80,
#  'Dust': 81,
#  'Heartbreak': 82,
#  "King's": 83,
#  'Monsieur': 84,
#  'Ballou': 85,
#  'Operation': 86,
#  "L')": 87,
#  'Their': 88,
#  "Warhol's": 89,
#  'sidste': 90,
#  'Piano,': 91,
#  'Andy': 92,
#  'Come': 93,
#  'Mowgli': 94,
#  'Sling': 95,
#  'Peking': 96,
#  'Than': 97,
#  'Magnum': 98,
#  'Cutting': 99,
#  'Monster': 100,
#  'Mask': 101,
#  'Xiu': 102,
#  'Lips': 103,
#  'Amy': 104,
#  '(Falkens': 105,
#  'Immortal': 106,
#  'Relations': 107,
#  'Jersey': 108,
#  'Surviving': 109,
#  'Locusts,': 110,
#  "Dinosaur's": 111,
#  'Navy': 112,
#  'Buena': 113,
#  '(Leggenda': 114,
#  'Killing,': 115,
#  'Roseanna)': 116,
#  'Germinal': 117,
#  'Dredd': 118,
#  'Roof,': 119,
#  'Pesos': 120,
#  'Vampires': 121,
#  'al': 122,
#  'Bondage': 123,
#  'Matewan': 124,
#  'Pink': 125,
#  'Lost': 126,
#  'Threesome': 127,
#  'Ninotchka': 128,
#  'Dingo': 129,
#  'Separation': 130,
#  'Illusions': 131,
#  'Row,': 132,
#  'Days': 133,
#  'Weird': 134,
#  'Patriot,': 135,
#  'Messenger:': 136,
#  'Bulworth': 137,
#  'Asphalt': 138,
#  'Septi�me': 139,
#  'Wing': 140,
#  'Harold': 141,
#  'Jakes,': 142,
#  'Denise': 143,
#  'Bullwinkle,': 144,
#  'Kull': 145,
#  'Parent': 146,
#  '1600': 147,
#  '(Callej�n': 148,
#  'Kwai,': 149,
#  'Hunchback': 150,
#  '(Keiner': 151,
#  'Tap': 152,
#  'Dog': 153,
#  'Professional,': 154,
#  'Wishmaster': 155,
#  'Gang': 156,
#  'Finding': 157,
#  "Mo'": 158,
#  'X-M': 159,
#  '(Auch': 160,
#  'Seasons,': 161,
#  'Maps': 162,
#  'Times': 163,
#  'Waltzes': 164,
#  'da': 165,
#  'McCullochs,': 166,
#  'Vincent,': 167,
#  'Kaspar': 168,
#  'Jude': 169,
#  'Dead,': 170,
#  'son': 171,
#  'Murder,': 172,
#  'Breaking': 173,
#  'Alan': 174,
#  'Scout,': 175,
#  'va)': 176,
#  'Panchali': 177,
#  'Around': 178,
#  'sources)': 179,
#  'Crow,': 180,
#  'cioccolata)': 181,
#  'Becomes': 182,
#  'Nobody': 183,
#  'Nighthawks': 184,
#  'Move': 185,
#  'Minnie': 186,
#  'League:': 187,
#  'Shiloh': 188,
#  'Framed': 189,
#  'Radioland': 190,
#  'castrato': 191,
#  'Washington': 192,
#  'We': 193,
#  'Hall': 194,
#  'Chamber,': 195,
#  'Outlaw,': 196,
#  'klein': 197,
#  'Toxie,': 198,
#  'Presents:': 199,
#  '2001:': 200,
#  'Sun,': 201,
#  'Eyre': 202,
#  'Legs': 203,
#  'Territory': 204,
#  'Friends': 205,
#  'Nina': 206,
#  'Himmel': 207,
#  'Sinbad,': 208,
#  'qin': 209,
#  'Sleep,': 210,
#  'Artaud)': 211,
#  'Calendar': 212,
#  "L'": 213,
#  'Cemetery': 214,
#  'Pop.': 215,
#  'Sun': 216,
#  'Apple': 217,
#  'Alice,': 218,
#  'Thirty-Two': 219,
#  'Tuned': 220,
#  'Kelly': 221,
#  'Basquiat': 222,
#  'Afternoon': 223,
#  'North': 224,
#  'Disturbing': 225,
#  'Killbots)': 226,
#  'Guerre,': 227,
#  "Ramblin'": 228,
#  'Claus:': 229,
#  'Neon': 230,
#  'Proxy,': 231,
#  'Game,': 232,
#  'Wolves,': 233,
#  'Alien�': 234,
#  'Perils': 235,
#  'Science': 236,
#  'Meteor': 237,
#  'Thief': 238,
#  'Rings,': 239,
#  'Pest,': 240,
#  'Impact': 241,
#  'Ducks,': 242,
#  'Palm': 243,
#  'Halloween:': 244,
#  'Spinnen,': 245,
#  'Sacco': 246,
#  'Bleu)': 247,
#  'Sleeper': 248,
#  'Mankind': 249,
#  'Spirits,': 250,
#  'Hippie': 251,
#  'Segno': 252,
#  'Callej�n': 253,
#  'Bordeaux': 254,
#  'Needful': 255,
#  'dvadesetiot': 256,
#  'Secrets': 257,
#  'Buckaroo': 258,
#  'Sparks': 259,
#  'Mute': 260,
#  'Plennik)': 261,
#  'Brooklyn': 262,
#  "You've": 263,
#  'Shoot': 264,
#  'Erin': 265,
#  'Until': 266,
#  'Fitzcarraldo': 267,
#  'Journal': 268,
#  'boca)': 269,
#  'B*A*P*S': 270,
#  'Local': 271,
#  'Rebecca': 272,
#  'Powder': 273,
#  "Muriel's": 274,
#  'Outlaws': 275,
#  'Goodbye': 276,
#  'Audrey': 277,
#  'Morning,': 278,
#  'Dorothy': 279,
#  'False': 280,
#  'Gambler,': 281,
#  'Yol': 282,
#  'Barrels': 283,
#  'Topaz': 284,
#  'Glengarry': 285,
#  'Express': 286,
#  'Sharks': 287,
#  '(Soy': 288,
#  'Breathless': 289,
#  'SS': 290,
#  'Herbie': 291,
#  'Heat': 292,
#  'James': 293,
#  'macor)': 294,
#  'Showgirls': 295,
#  'Batch': 296,
#  'et': 297,
#  'Demolition': 298,
#  'Periscope': 299,
#  'Indiana': 300,
#  'Tennis': 301,
#  'Natty': 302,
#  '1975': 303,
#  '(S�ndagsengler)': 304,
#  'October,': 305,
#  'Shanghai': 306,
#  'Sugar': 307,
#  'Talk': 308,
#  'Ivy': 309,
#  'Boys,': 310,
#  'Browne': 311,
#  'Largo': 312,
#  'Network': 313,
#  "Lilian's": 314,
#  'Minded': 315,
#  'Bible,': 316,
#  '(Central': 317,
#  'Program,': 318,
#  'Driving': 319,
#  'Bottom': 320,
#  'Shave,': 321,
#  'Front': 322,
#  'Yojimbo': 323,
#  'Bunch': 324,
#  'Cross': 325,
#  "Brother's": 326,
#  'Goat': 327,
#  'Patton': 328,
#  'Kindred,': 329,
#  'Uzala': 330,
#  'Feast': 331,
#  'Possession': 332,
#  'Africa,': 333,
#  'Plaid': 334,
#  'Children,': 335,
#  'Fletch': 336,
#  'Nueba': 337,
#  'Bound': 338,
#  'People': 339,
#  'Age,': 340,
#  'Sour': 341,
#  'Slam': 342,
#  'Artaud': 343,
#  'Camelot': 344,
#  "Bustin'": 345,
#  'March': 346,
#  'You': 347,
#  'Bed': 348,
#  'Feet': 349,
#  'Re-Animator': 350,
#  'Boy,': 351,
#  'Shoulder': 352,
#  'Josey': 353,
#  'Gift,': 354,
#  'Impossible': 355,
#  'Contender,': 356,
#  'Labyrinth': 357,
#  'Fresh': 358,
#  '.45': 359,
#  'Flintstones': 360,
#  "(God's": 361,
#  'Goldfinger': 362,
#  'Feind)': 363,
#  'Bros.': 364,
#  'Kundun': 365,
#  'Jafar,': 366,
#  'Consequences,': 367,
#  'Majesty,': 368,
#  'Broke,': 369,
#  '(Operazione': 370,
#  'Spot,': 371,
#  'Awfully': 372,
#  'Son,': 373,
#  'Groundhog': 374,
#  'Ognja': 375,
#  'Dudley': 376,
#  'd�but': 377,
#  'Hang': 378,
#  "Cuckoo's": 379,
#  'Ordinary': 380,
#  'Moonlight': 381,
#  'gaiwak)': 382,
#  'tianshi': 383,
#  "Kestrel's": 384,
#  'Solaris': 385,
#  'Rage)': 386,
#  '(De': 387,
#  'Lo': 388,
#  'Full': 389,
#  'Gang,': 390,
#  'Stupids,': 391,
#  'Playing': 392,
#  'Suicides,': 393,
#  'Legends:': 394,
#  'Cole,': 395,
#  'Dear': 396,
#  'Whole': 397,
#  'Yesterday': 398,
#  'Doors,': 399,
#  'Club,': 400,
#  'Condor': 401,
#  'Cheap': 402,
#  'Suspicion': 403,
#  'Scream': 404,
#  'Parallel': 405,
#  'di': 406,
#  'If....': 407,
#  'Girl,': 408,
#  'Ninth': 409,
#  '(Schrei': 410,
#  'Die': 411,
#  'Command': 412,
#  'Microcosmos': 413,
#  'Daytrippers,': 414,
#  'Amazing': 415,
#  'bolle': 416,
#  'Ugly,': 417,
#  'Leather': 418,
#  'Aardman': 419,
#  'Scrooged': 420,
#  'Hillbillys': 421,
#  'Antonin': 422,
#  'Bewegte': 423,
#  'Female': 424,
#  'Must': 425,
#  'Violenza': 426,
#  'Newmar': 427,
#  'Line': 428,
#  'Sleepwalkers': 429,
#  '(Sibak)': 430,
#  'Babe': 431,
#  'Sid': 432,
#  'Dreaming': 433,
#  'Fire,': 434,
#  'angefangen)': 435,
#  'Supper,': 436,
#  'Lambs,': 437,
#  'London,': 438,
#  "Pharaoh's": 439,
#  'Mickey': 440,
#  'Del': 441,
#  'Abominable': 442,
#  'Vu': 443,
#  'Savage': 444,
#  'Bandit': 445,
#  'Separation,': 446,
#  'Innocent': 447,
#  'Bewitched,': 448,
#  'Professore!': 449,
#  'Sundance': 450,
#  "Charm's": 451,
#  'Horse': 452,
#  'Penny': 453,
#  'Navarone,': 454,
#  'Amityville:': 455,
#  'Trek': 456,
#  'Letter': 457,
#  'Engel)': 458,
#  'Crossing': 459,
#  'ge': 460,
#  'Irene': 461,
#  'Loved': 462,
#  'Knot': 463,
#  'Hate,': 464,
#  'Inspector': 465,
#  'End': 466,
#  'Velvet': 467,
#  'NIMH,': 468,
#  'Fear:': 469,
#  'Half': 470,
#  'Mulholland': 471,
#  'Love,': 472,
#  'Vie)': 473,
#  'Little': 474,
#  'Voices,': 475,
#  'vida': 476,
#  'Sorcerer': 477,
#  'Quest': 478,
#  'Professional)': 479,
#  'Freedom': 480,
#  'Entertaining': 481,
#  'Cigarettes': 482,
#  'Lamerica': 483,
#  'Gilda': 484,
#  'Smell': 485,
#  'Degrees': 486,
#  'Shine': 487,
#  'Web': 488,
#  'Crisis': 489,
#  'T-Men': 490,
#  'Cold,': 491,
#  'Heathers': 492,
#  'Senior': 493,
#  'Foo,': 494,
#  'Wedding': 495,
#  'Dracula': 496,
#  'Designated': 497,
#  'Liaison': 498,
#  'Badlands': 499,
#  'Stone': 500,
#  'B.': 501,
#  'dou': 502,
#  'Room': 503,
#  'Sunrise': 504,
#  'Asfour': 505,
#  'Meet': 506,
#  "Mat'": 507,
#  'Costa': 508,
#  'Zhivago': 509,
#  'Earthbound': 510,
#  'quan)': 511,
#  'Effect,': 512,
#  'In': 513,
#  'Lesson,': 514,
#  'Topsy-Turvy': 515,
#  'Sorority': 516,
#  'Sefid': 517,
#  'Spanking': 518,
#  'Source,': 519,
#  'Armed': 520,
#  'Tigger': 521,
#  'Earp': 522,
#  'il': 523,
#  'Willow': 524,
#  'qui': 525,
#  '98': 526,
#  'Follia)': 527,
#  'Much,': 528,
#  'Run': 529,
#  'Raven,': 530,
#  'Patient,': 531,
#  'Passage': 532,
#  'Hollywood': 533,
#  'Odyssey': 534,
#  'Kagemusha': 535,
#  'Bram': 536,
#  'Paura,': 537,
#  'Paycock': 538,
#  'Fishes': 539,
#  'Marked': 540,
#  '(Jing': 541,
#  'Gone': 542,
#  'Hype,': 543,
#  'Joan': 544,
#  'Breathing': 545,
#  'Carnale)': 546,
#  'Zoe': 547,
#  'klaka)': 548,
#  'Virgin': 549,
#  'Calls': 550,
#  'Captives': 551,
#  '(Travolti': 552,
#  'Navarone': 553,
#  'Spirits': 554,
#  'Wanna': 555,
#  'Got': 556,
#  '39': 557,
#  'Human,': 558,
#  'Valentino': 559,
#  'que': 560,
#  'Runnings': 561,
#  'Shots': 562,
#  'Slumberland': 563,
#  'Face,': 564,
#  'Wonders': 565,
#  '(Mia': 566,
#  'U2:': 567,
#  'Crows': 568,
#  'Arrest': 569,
#  'dozhdot)': 570,
#  'Barb': 571,
#  'hui)': 572,
#  'Lead': 573,
#  'Circle,': 574,
#  'Guinevere': 575,
#  '7': 576,
#  "Marvin's": 577,
#  'About': 578,
#  'Jaguar': 579,
#  'ojos)': 580,
#  'Crow:': 581,
#  'Palace,': 582,
#  'Waterworld': 583,
#  'Slaves': 584,
#  'Grace': 585,
#  'Tramp': 586,
#  'Might': 587,
#  '(K�disbellan': 588,
#  'League': 589,
#  'Died': 590,
#  '20th': 591,
#  'Knights,': 592,
#  'as': 593,
#  'Retrouv�)': 594,
#  'Paulie': 595,
#  'Guys': 596,
#  'Saphead,': 597,
#  'Beginning': 598,
#  'Bowles': 599,
#  'para': 600,
#  'Theory': 601,
#  'Thoughts': 602,
#  'Wine': 603,
#  'Benjamenta,': 604,
#  'Ladyhawke': 605,
#  'Heart': 606,
#  'Goodnight,': 607,
#  'X-Files:': 608,
#  '(Feiying': 609,
#  'Jonah': 610,
#  'Week': 611,
#  'Sum': 612,
#  'Dellamore)': 613,
#  'La)': 614,
#  'Loaded': 615,
#  'Grit': 616,
#  'Very': 617,
#  'Police': 618,
#  '(Dead': 619,
#  'Grapes': 620,
#  'Polar)': 621,
#  'Trial,': 622,
#  'Fancy': 623,
#  'Helena': 624,
#  'Go': 625,
#  'syn': 626,
#  'Cool': 627,
#  'Chasing': 628,
#  'coups)': 629,
#  'Pagemaster,': 630,
#  'Extra-Terrestrial': 631,
#  'Fruit': 632,
#  'Cheerleader': 633,
#  'Firm,': 634,
#  'Condition': 635,
#  'Character': 636,
#  '1st': 637,
#  'Madness': 638,
#  'Paper,': 639,
#  '(Abre': 640,
#  'Heads': 641,
#  "Heinlein's": 642,
#  'Catastrophes': 643,
#  'Remagen,': 644,
#  'Rush,': 645,
#  'Parker': 646,
#  'III,': 647,
#  'Endless': 648,
#  'Beautiful': 649,
#  'Is': 650,
#  'Pussycat!': 651,
#  'Incognito': 652,
#  'Waiting': 653,
#  'Juction': 654,
#  'Murder!': 655,
#  'Corrina,': 656,
#  'Bug,': 657,
#  'Shrews,': 658,
#  'Gate,': 659,
#  'Still,': 660,
#  'Wally': 661,
#  '(Zui': 662,
#  'Postino,': 663,
#  'William': 664,
#  'Bleeding': 665,
#  'Lisa': 666,
#  'Indochine': 667,
#  'peuple': 668,
#  'en': 669,
#  'Priest': 670,
#  'Dwarf,': 671,
#  'I.Q.': 672,
#  'Oz,': 673,
#  'Voyage': 674,
#  'Kentucky': 675,
#  'Rangoon': 676,
#  'Cujo': 677,
#  "Schindler's": 678,
#  'Room,': 679,
#  'Turning,': 680,
#  'Warrior)': 681,
#  'dao': 682,
#  'Frankie': 683,
#  'Show,': 684,
#  "Don't": 685,
#  'Cape': 686,
#  'Millionaire,': 687,
#  'Tess': 688,
#  'Kombat': 689,
#  'Evening': 690,
#  'Amants': 691,
#  'Rose': 692,
#  'Fled': 693,
#  'Titus': 694,
#  '(Yi': 695,
#  'Annihilation': 696,
#  'Dumber': 697,
#  'Tomb,': 698,
#  "Murphy's": 699,
#  'Dreamed': 700,
#  'Barcelona': 701,
#  'Jumanji': 702,
#  'Beloved': 703,
#  "Can't": 704,
#  'Solari)': 705,
#  'Hills': 706,
#  'Tainted': 707,
#  'Halloween': 708,
#  'Hat': 709,
#  'Tilt': 710,
#  'Bicycle': 711,
#  'Shadrach': 712,
#  'Carnosaur': 713,
#  'Jericho': 714,
#  '81': 715,
#  'After,': 716,
#  'Beach': 717,
#  'God': 718,
#  '(Zerkalo)': 719,
#  'Buffy': 720,
#  'Assignment,': 721,
#  'Skipped': 722,
#  'enfants': 723,
#  'Know': 724,
#  'Cat!': 725,
#  'Ghosts': 726,
#  'Chopping': 727,
#  'Little,': 728,
#  'Glenn': 729,
#  'Cupboard,': 730,
#  'Passi': 731,
#  'Welt)': 732,
#  'Beavis': 733,
#  'Quiet': 734,
#  'Future,': 735,
#  'Cleaning': 736,
#  'Unforgotten:': 737,
#  'Shooter,': 738,
#  'Cup,': 739,
#  '(Der': 740,
#  "Love's": 741,
#  'Risky': 742,
#  'Saves': 743,
#  'Tide': 744,
#  'Interiors': 745,
#  'Wore': 746,
#  'Bloodsport': 747,
#  '(Bacheha-Ye': 748,
#  'Nine': 749,
#  'Corruptor,': 750,
#  'There,': 751,
#  'Howling': 752,
#  'Autumn': 753,
#  'Wales,': 754,
#  'Tibet': 755,
#  '(Corpi': 756,
#  'Hellraiser': 757,
#  '8MM': 758,
#  'Nil': 759,
#  'Distress,': 760,
#  'Journals': 761,
#  'Waterboy,': 762,
#  'D.A.,': 763,
#  'destino': 764,
#  'Celtic': 765,
#  'Tracy': 766,
#  'X:': 767,
#  'Woke': 768,
#  'Bank': 769,
#  'Nightmares': 770,
#  'Journey': 771,
#  '(ID4)': 772,
#  'ce': 773,
#  'Road': 774,
#  'Clear': 775,
#  'Specialist,': 776,
#  'Gesture,': 777,
#  'Emerald': 778,
#  'Limbo': 779,
#  'Polish': 780,
#  'Mamma': 781,
#  '(E': 782,
#  'Memories': 783,
#  'Thumbelina': 784,
#  'Terrorist,': 785,
#  'Stir': 786,
#  'mich)': 787,
#  'Jungle': 788,
#  'Strangers': 789,
#  'Atlantic': 790,
#  'Ravenous': 791,
#  'Conqueror': 792,
#  'Beetlejuice': 793,
#  'Blazing': 794,
#  'Pop': 795,
#  'Day,': 796,
#  'Attraction': 797,
#  'Comes': 798,
#  "Wayne's": 799,
#  'Urban': 800,
#  'Empty': 801,
#  'Mulan': 802,
#  'Law,': 803,
#  '(Idioterne)': 804,
#  '(Longxiong': 805,
#  'Telling': 806,
#  'Hunted': 807,
#  'Rudy': 808,
#  'Coney': 809,
#  'Zulu': 810,
#  'Mediterraneo': 811,
#  'Passion': 812,
#  'Preferred...': 813,
#  'Excess': 814,
#  'Hoogste': 815,
#  'Bachelor,': 816,
#  'Time': 817,
#  'Annie': 818,
#  'Hornblower': 819,
#  'Speechless': 820,
#  'Armageddon': 821,
#  'Locomotive': 822,
#  'Arlington': 823,
#  'Tommy': 824,
#  'Kill': 825,
#  'Less': 826,
#  'Faces,': 827,
#  'Advocate,': 828,
#  'Doctor': 829,
#  'Christ,': 830,
#  'Smith': 831,
#  'Romper': 832,
#  'Question,': 833,
#  'Ever': 834,
#  'Sticky': 835,
#  '13': 836,
#  'Leopold': 837,
#  'Steamboat': 838,
#  'Santa': 839,
#  'gar�on': 840,
#  "Sullivan's": 841,
#  'Khoda)': 842,
#  'Barry': 843,
#  'Company': 844,
#  'Nadine': 845,
#  'Powers:': 846,
#  'Baton': 847,
#  'Sugarland': 848,
#  'Damsel': 849,
#  'Wisdom': 850,
#  'Closer': 851,
#  'Desire': 852,
#  'Fair': 853,
#  '(Io': 854,
#  '(En': 855,
#  'He': 856,
#  'Head': 857,
#  'Critical': 858,
#  'Would': 859,
#  'Roxbury,': 860,
#  'Johnny': 861,
#  'Tora!': 862,
#  'Solas': 863,
#  'Monument': 864,
#  'Hyena)': 865,
#  'Clouds,': 866,
#  'Home:': 867,
#  'Jefferson': 868,
#  '54': 869,
#  'Habit': 870,
#  'Far': 871,
#  'Bag': 872,
#  'shuang': 873,
#  'Miami': 874,
#  'Morant': 875,
#  'Rosewood': 876,
#  'Pitch': 877,
#  'Of': 878,
#  'Noon': 879,
#  'Federal': 880,
#  'L.A.': 881,
#  'A.': 882,
#  'Strong': 883,
#  'Dollars,': 884,
#  'Brava': 885,
#  'Coast,': 886,
#  'Retro': 887,
#  'Superweib,': 888,
#  'Rosencrantz': 889,
#  'Chuck': 890,
#  'Sin': 891,
#  "d'Agosto)": 892,
#  '(Bian': 893,
#  'Clan': 894,
#  'Lin:': 895,
#  'Chinois': 896,
#  '(Mitt': 897,
#  'Common': 898,
#  'Left': 899,
#  'Auntie': 900,
#  'cousin!': 901,
#  'Return': 902,
#  'Bodeos)': 903,
#  'Apes': 904,
#  'Modern': 905,
#  'Cherbourg,': 906,
#  'Gillian': 907,
#  'Christmas': 908,
#  'Perversions': 909,
#  'Prince': 910,
#  'Desperate': 911,
#  'Broadcast': 912,
#  'Mifune': 913,
#  'Coyote': 914,
#  'Pet': 915,
#  'Panther,': 916,
#  'Pointe': 917,
#  'Creatures': 918,
#  'Rapture,': 919,
#  'Affair': 920,
#  'Men,': 921,
#  'King,': 922,
#  'stelle,': 923,
#  'Alabama': 924,
#  'G.I.': 925,
#  'Sons': 926,
#  'Combo,': 927,
#  'Rabbit?': 928,
#  'Naturally': 929,
#  'Sting,': 930,
#  'Jewel': 931,
#  '(Rekopis': 932,
#  'Honor': 933,
#  'Ligeia,': 934,
#  'I': 935,
#  'Reunion': 936,
#  'Plan�te': 937,
#  'Ladder': 938,
#  'Brain': 939,
#  'On': 940,
#  'Dugan': 941,
#  'Ayn': 942,
#  'Do-Right': 943,
#  'Ocean,': 944,
#  'Terms': 945,
#  'Beauties': 946,
#  'Oficial)': 947,
#  'Dawn)': 948,
#  'Tail:': 949,
#  '(Haine,': 950,
#  'Criminals': 951,
#  'Die,': 952,
#  'Lawn': 953,
#  'Dragons': 954,
#  'Martin)': 955,
#  'Halfmoon': 956,
#  'rennt)': 957,
#  'Seeking': 958,
#  'Deadtime': 959,
#  'Dolores': 960,
#  '(Chao': 961,
#  'Jesse': 962,
#  'To': 963,
#  'VII:': 964,
#  "'77": 965,
#  'Misery': 966,
#  'arriv�': 967,
#  'Railroad': 968,
#  'Daughter': 969,
#  'Stein)': 970,
#  'Rent-a-Kid': 971,
#  'Paralyzing': 972,
#  'Tequila': 973,
#  'Convent,': 974,
#  'Guts,': 975,
#  'West': 976,
#  'Dying': 977,
#  'Det)': 978,
#  'Sgt.': 979,
#  'Hillbillies,': 980,
#  'Swept': 981,
#  'D�ner': 982,
#  'Hurricane,': 983,
#  'Clause,': 984,
#  'Eighty-Four': 985,
#  'Alarmist,': 986,
#  'Roy': 987,
#  'Everything': 988,
#  'Ruth': 989,
#  'Snake': 990,
#  '(Retour': 991,
#  'Shrew,': 992,
#  'Henge)': 993,
#  'Flier': 994,
#  'Lured': 995,
#  'Sierra': 996,
#  'Maltese': 997,
#  'Story': 998,
#  'True': 999,
#  ...}

# %%
#将电影Title转成等长数字列表，长度是15
title_count = 15
title_map = {val:[title2int[row] for row in val.split()] for ii,val in enumerate(set(movies['Title']))}

for key in title_map:
    for cnt in range(title_count - len(title_map[key])):
        title_map[key].insert(len(title_map[key]) + cnt,title2int['<PAD>'])

movies['Title'] = movies['Title'].map(title_map)

# %%
movies['Title'][100]
# Out:
# [4115,
#  4975,
#  4982,
#  4982,
#  4982,
#  4982,
#  4982,
#  4982,
#  4982,
#  4982,
#  4982,
#  4982,
#  4982,
#  4982,
#  4982]

# %%
movies_orig[100]
# Out:
# array([102, 'Mr. Wrong (1996)', 'Comedy'], dtype=object)

# %%
list(title2int.keys())[list(title2int.values()).index(2870)]
# Out:
# 'Mission'

# %%
list(title2int.keys())[list(title2int.values()).index(3789)]
# Out:
# 'Arizona'

# %%
list(title2int.keys())[list(title2int.values()).index(3476)]
# Out:
# 'Chips'

# %%
def load_data():
    """
    Load Dataset from File
    """
    # 读取User数据
    users_title = ['UserID', 'Gender', 'Age', 'JobID', 'Zip-code']
    users = pd.read_table('./ml-1m/users.dat', sep='::', header=None, names=users_title, engine = 'python')
    users = users.filter(regex='UserID|Gender|Age|JobID')
    users_orig = users.values
    # 改变User数据中性别和年龄
    gender_map = {'F':0, 'M':1}
    users['Gender'] = users['Gender'].map(gender_map)

    age_map = {item:index for index,item in enumerate([1,18,25,35,45,50,56])}
    users['Age'] = users['Age'].map(age_map)

    # 读取Movie数据集
    movies_title = ['MovieID', 'Title', 'Genres']
    movies = pd.read_table('./ml-1m/movies.dat', sep='::', header=None, names=movies_title, engine = 'python')
    movies_orig = movies.values
    # 将Title中的年份去掉
    pattern = re.compile(r'^(.*)\((\d+)\)$')

    title_map = {item:pattern.match(item).group(1) for index,item in enumerate(set(movies['Title']))}
    movies['Title'] = movies['Title'].map(title_map)

    # 电影类型转数字字典
    genres_set = set()
    for item in movies['Genres'].str.split('|'):
        genres_set.update(item)

    genres_set.add('<PAD>')
    genres2int = {item:index for index,item in enumerate(genres_set)}

    # 将电影类型转成等长数字列表，长度是18
    genres_map = {item:[genres2int[row] for row in item.split('|')] for index,item in enumerate(set(movies['Genres']))}

    for key in genres_map:
        for cnt in range(max(genres2int.values()) - len(genres_map[key])):
            genres_map[key].insert(len(genres_map[key]) + cnt,genres2int['<PAD>'])
    
    movies['Genres'] = movies['Genres'].map(genres_map)

    # 电影Title转数字字典
    title_set = set()
    for val in movies['Title'].str.split():
        title_set.update(val)
    
    title_set.add('<PAD>')
    title2int = {val:ii for ii, val in enumerate(title_set)}

    # 将电影Title转成等长数字列表，长度是15
    title_count = 15
    title_map = {item:[title2int[row] for row in item.split()] for index,item in enumerate(set(movies['Title']))}
    
    for key in title_map:
        for cnt in range(title_count - len(title_map[key])):
            title_map[key].insert(len(title_map[key]) + cnt,title2int['<PAD>'])
    
    movies['Title'] = movies['Title'].map(title_map)

    # 读取评分数据集
    ratings_title = ['UserID','MovieID', 'ratings', 'timestamps']
    ratings = pd.read_table('./ml-1m/ratings.dat', sep='::', header=None, names=ratings_title, engine = 'python')
    ratings = ratings.filter(regex='UserID|MovieID|ratings')

    # 合并三个表
    data = pd.merge(pd.merge(ratings, users), movies)
    
    # 将数据分成X和y两张表
    target_fields = ['ratings']
    features_pd, targets_pd = data.drop(target_fields, axis=1), data[target_fields]
    
    features = features_pd.values
    targets_values = targets_pd.values
    
    return title_count, title_set, genres2int, features, targets_values, ratings, users, movies, data, movies_orig, users_orig

# %%
title_count, title_set, genres2int, features, targets_values, ratings, users, movies, data, movies_orig, users_orig = load_data()

# %%
data.head()
# Out:
#    UserID  MovieID  ratings  Gender  Age  JobID  \
# 0       1     1193        5       0    0     10
# 1       2     1193        5       1    6     16
# 2      12     1193        4       1    2     12
# 3      15     1193        4       1    2      7
# 4      17     1193        5       1    5      1
#
#                                                Title  \
# 0  [2077, 3571, 3400, 1316, 379, 3314, 4982, 4982...
# 1  [2077, 3571, 3400, 1316, 379, 3314, 4982, 4982...
# 2  [2077, 3571, 3400, 1316, 379, 3314, 4982, 4982...
# 3  [2077, 3571, 3400, 1316, 379, 3314, 4982, 4982...
# 4  [2077, 3571, 3400, 1316, 379, 3314, 4982, 4982...
#
#                                               Genres
# 0  [9, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, ...
# 1  [9, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, ...
# 2  [9, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, ...
# 3  [9, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, ...
# 4  [9, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, ...

# %%
features
# Out:
# array([[1, 1193, 0, ..., 10,
#         [2077, 3571, 3400, 1316, 379, 3314, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982],
#         [9, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8]],
#        [2, 1193, 1, ..., 16,
#         [2077, 3571, 3400, 1316, 379, 3314, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982],
#         [9, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8]],
#        [12, 1193, 1, ..., 12,
#         [2077, 3571, 3400, 1316, 379, 3314, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982],
#         [9, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8]],
#        ...,
#        [5780, 2845, 1, ..., 17,
#         [4419, 2803, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982],
#         [9, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8]],
#        [5851, 3607, 0, ..., 20,
#         [2077, 474, 2453, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982],
#         [6, 9, 13, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8]],
#        [5938, 2909, 1, ..., 1,
#         [1269, 2979, 3369, 2510, 2628, 1013, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982],
#         [10, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8]]], dtype=object)

# %%
features.take(0,1)
# Out:
# array([1, 2, 12, ..., 5780, 5851, 5938], dtype=object)

# %%
# Count Plot (a.k.a. Bar Plot)
sns.countplot(x='Type 1', data=df, palette=None)
 
# Rotate x-labels
plt.xticks(rotation=-45)
